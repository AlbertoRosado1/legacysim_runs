# %%
import sys
sys.path.append("/global/homes/a/arosado/photometry/")

# %%
import os
import logging
import numpy as np
import fitsio as ft
from matplotlib import pyplot as plt

from photometry import TargetSelection, utils, setup_logging

# %% [markdown]
# I used `ELGzdone_full_noveto.dat.fits` while Arnaud used `ELGzdone_full.dat.fits`

# %%
import os
import logging
import numpy as np
import fitsio as ft
from matplotlib import pyplot as plt

from photometry import TargetSelection, utils, setup_logging

logger = logging.getLogger('DA02')
setup_logging()

plot_dir = '/global/homes/a/arosado/legacysim_runs/DA02/plots'
run = 'north'
region = run[0].upper()
base_dir = '/global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2'
data_fn = os.path.join(base_dir, 'ELGzdone_full_noveto.dat.fits')
randoms_fn = os.path.join(base_dir, 'ELGzdone_0_full_noveto.ran.fits')
hp_fn = '/global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits'
legacysim_fn = os.path.join(os.getenv('CSCRATCH'),'legacysim','dr9','DA02',run,'file0_rs0_skip0','merged','adematti_matched_input.fits')
logger.info('Filename: {}'.format(legacysim_fn))
# Out:
# [ 000000.00 ]: 06-05 16:32  DA02            INFO     Filename: /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/adematti_matched_input.fits

# %%
my_base_dir = '/global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2'
my_data_fn = os.path.join(base_dir, 'ELGzdone_full_noveto.dat.fits')
my_randoms_fn = os.path.join(base_dir, 'ELGzdone_0_full_noveto.ran.fits')
my_legacysim_fn = os.path.join(os.getenv('CSCRATCH'),'legacysim','dr9','DA02',run,'file0_rs0_skip0','merged','matched_inputs_concatenated.fits')
logger.info('Filename: {}'.format(my_legacysim_fn))
# Out:
# [ 000001.09 ]: 06-05 16:32  DA02            INFO     Filename: /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/matched_inputs_concatenated.fits

# %% [markdown]
# # Functions

# %%
def isELG_colors(gflux=None, rflux=None, zflux=None, w1flux=None,
                 w2flux=None, gfiberflux=None, south=True, primary=None,
                 gmarg=0., grmarg=0., rzmarg=0.):
    """
    Apply ELG selection with box enlarged by ``gmarg``, ``grmarg``, ``rzmarg``.

    SV3 selection from https://github.com/desihub/desitarget/blob/7786db0931d23ed20de7ef37a6f07a52072e11ab/py/desitarget/sv3/sv3_cuts.py#L526
    """
    if primary is None:
        primary = np.ones_like(rflux, dtype='?')
    elg = primary.copy()

    # ADM work in magnitudes instead of fluxes. NOTE THIS IS ONLY OK AS
    # ADM the snr masking in ALL OF g, r AND z ENSURES positive fluxes.
    g = 22.5 - 2.5*np.log10(gflux.clip(1e-16))
    r = 22.5 - 2.5*np.log10(rflux.clip(1e-16))
    z = 22.5 - 2.5*np.log10(zflux.clip(1e-16))
    gfib = 22.5 - 2.5*np.log10(gfiberflux.clip(1e-16))

    # ADM cuts shared by the northern and southern selections.
    elg &= g > 20 - gmarg                # bright cut.
    elg &= r - z > 0.15 - rzmarg         # blue cut.
#    elg &= r - z < 1.6 + rzmarg         # red cut.

    # ADM cuts that are unique to the north or south. Identical for sv3
    # ADM but keep the north/south formalism in case we use it later.
    if south:
        elg &= gfib < 24.1 + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.
    else:
        elg &= gfib < 24. + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.

    # ADM separate a low-priority and a regular sample.
    elgvlo = elg.copy()

    # ADM low-priority OII flux cut.
    elgvlo &= g - r < -1.2*(r - z) + 1.6 + grmarg
    elgvlo &= g - r >= -1.2*(r - z) + 1.3 - grmarg

    # ADM high-priority OII flux cut.
    elg &= g - r < -1.2*(r - z) + 1.3 + grmarg

    return elgvlo, elg


def mask_ts(self,key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region,gmarg=0.,grmarg=0.,rzmarg=0.,gcut=-np.inf):
    mask = isELG_colors(gflux=self['{}_G'.format(key_flux)],rflux=self['{}_R'.format(key_flux)],
                        zflux=self['{}_Z'.format(key_flux)],gfiberflux=self['{}_G'.format(key_fiberflux)],south=region=='S',
                        gmarg=gmarg,grmarg=grmarg,rzmarg=rzmarg)
    mask = mask[0] | mask[1]
    mask &= self['{}_G'.format(key_flux)] > gcut
    return mask

TargetSelection.mask_ts = mask_ts

# %% [markdown]
# # Code

# %% [markdown]
# Get bricks that are same for both runs

# %%
my_bricks = np.unique(ft.FITS(my_legacysim_fn)[1]['input_brickname'][:])
adematti_bricks = np.unique(ft.FITS(legacysim_fn)[1]['input_brickname'][:])
mask = np.isin(adematti_bricks, my_bricks)
bricks2use = adematti_bricks[mask]
bricks2use.size
# Out:
# 10343

# %% [markdown]
# Arnaud's results (only choose bricks in my run)

# %%
# legacysim
legacysim = TargetSelection.load_objects(legacysim_fn, radecbox=None, tracer='ELG', region=None)
legacysim.set_upper_case()

# here we select only the bricks I ran
compare_mask = np.isin(legacysim['INPUT_BRICKNAME'], bricks2use)
legacysim = legacysim[compare_mask]

#continue the same as always
legacysim['RA'] = legacysim['INPUT_RA']
legacysim['DEC'] = legacysim['INPUT_DEC']
#legacysim['MATCHED'] = legacysim['DISTANCE'] < 0.15/3600.
logger.info('Found {:d}/{:d} matches.'.format(legacysim['MATCHED'].sum(),legacysim.size))
for b in legacysim.bands:
    legacysim['INPUT_EFLUX_{}'.format(b)] = utils.mag_to_flux(legacysim['INPUT_{}'.format(b)])
legacysim['INPUT_EFIBERFLUX_G'] = utils.mag_to_flux(legacysim['INPUT_GFIBER'])
legacysim.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
legacysim['EFIBERFLUX_G'] = legacysim.estimated_flux('G',key_transmission='MW_TRANSMISSION',key_flux='FIBERFLUX')
mask_tsin = legacysim.mask_ts(key_flux='INPUT_EFLUX',key_fiberflux='INPUT_EFIBERFLUX',region=region)
#mask_tsin &= legacysim.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
mask_tsout = legacysim.mask_ts(key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region) & legacysim['MATCHED']
#mask_tsout &= legacysim.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
logger.info('Selecting {:d} (output)/{:d} (input) injected sources.'.format(mask_tsout.sum(),mask_tsin.sum()))
legacysim_data = legacysim[mask_tsout]
legacysim_randoms = legacysim[mask_tsin]
# Out:
# [ 000044.57 ]: 06-05 16:33  Catalogue       INFO     Loading catalogue /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/adematti_matched_input.fits.
# [ 000064.25 ]: 06-05 16:33  TargetSelection INFO     Selecting 5592566/5592566 targets.
# [ 000094.64 ]: 06-05 16:34  DA02            INFO     Found 3857265/5590404 matches.
# [ 000097.51 ]: 06-05 16:34  DA02            INFO     Selecting 212836 (output)/178166 (input) injected sources.

# %%
np.unique(legacysim['INPUT_BRICKNAME']).size
# Out:
# 10343

# %% [markdown]
# ## plotting Arnaud's

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)
legacysim_dens = HealpixDensity(map=map)
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)
filename = os.path.join(plot_dir,'adematti_footprint_{}.png'.format(run))
legacysim_dens.plot_density_map(title='legacysim density variations',vmin=0,vmax=2)
# Out:
# [ 000122.88 ]: 06-05 16:34  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000123.31 ]: 06-05 16:34  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000123.33 ]: 06-05 16:34  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000123.33 ]: 06-05 16:34  HealpixDensity  INFO     Found 13674 bricks with randoms.

# %%
spectro = True

def mask_data_zok(data, dchi2=0.9, tsnrcut=80):
    mask = data['o2c'] > dchi2
    mask &= data['ZWARN']*0 == 0
    mask &= data['ZWARN'] != 999999
    mask &= data['LOCATION_ASSIGNED'] == 1
    mask &= data['TSNR2_ELG'] > tsnrcut
    return mask

def mask_randoms_zok(randoms, tsnrcut=80):
    mask = randoms['TSNR2_ELG'] > tsnrcut
    return mask

# ELG targets, TS applied already
bricknames = np.unique(legacysim['BRICKNAME'])
logger.info('Found {:d} bricknames'.format(bricknames.size))
data = TargetSelection.load_objects(data_fn,region=region)

mask = np.in1d(data['BRICKNAME'],bricknames)
#mask[:] = True # do not cut data on the same bricks as legacysim
data.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
data['EFIBERFLUX_G'] = data.estimated_flux('G',key_transmission='MW_TRANSMISSION',key_flux='FIBERFLUX')
data.set_mag_from_flux(key_flux='EFLUX')

mask &= data.mask_ts(key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region)
#mask &= data.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
if spectro: mask &= mask_data_zok(data)
data['WEIGHT'] = data.ones()
nreal = 128
#nassign = nreal*data['PROB_OBS'] + 1. #assignment in actual observation counts
#if spectro: data['WEIGHT'] *= (nreal+1)/nassign
if spectro: data['WEIGHT'] *= 1/data['FRACZ_TILELOCID']
logger.info('Selecting {:d}/{:d} targets.'.format(mask.sum(), mask.size))
data = data[mask]

randoms = TargetSelection.load_objects(randoms_fn,region=region)
from desiutil.brick import Bricks
randoms['BRICKNAME'] = Bricks().brickname(randoms['RA'], randoms['DEC'])

mask = np.in1d(randoms['BRICKNAME'],bricknames)
#mask[:] = True
#mask &= randoms.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
if spectro: mask &= mask_randoms_zok(randoms)
randoms = randoms[mask]

def from_map(cat, fields):
    import healpy as hp
    map = Catalogue.load(hp_fn)
    theta,phi = utils.radec_to_thphi(cat['RA'],cat['DEC'])
    hppix = hp.ang2pix(map.header['HPXNSIDE'],theta,phi,nest=map.header['HPXNEST'],lonlat=False)
    for field in fields: cat[field] = map[field][hppix]
# Out:
# [ 000128.29 ]: 06-05 16:34  DA02            INFO     Found 10344 bricknames
# [ 000128.29 ]: 06-05 16:34  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2/ELGzdone_full_noveto.dat.fits.
# [ 000153.82 ]: 06-05 16:35  TargetSelection INFO     Selecting 1388368/4424177 targets.
# <ipython-input-10-f1bb1b9a7c97>:33: RuntimeWarning: divide by zero encountered in true_divide
#   if spectro: data['WEIGHT'] *= 1/data['FRACZ_TILELOCID']
# [ 000158.76 ]: 06-05 16:35  DA02            INFO     Selecting 61967/1388368 targets.
# [ 000159.27 ]: 06-05 16:35  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2/ELGzdone_0_full_noveto.ran.fits.
# [ 000166.82 ]: 06-05 16:35  TargetSelection INFO     Selecting 1423842/4471075 targets.

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)
legacysim_dens = HealpixDensity(map=map)
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)
filename = os.path.join(plot_dir,'adematti_footprint_{}.png'.format(run))
legacysim_dens.plot_density_map(title='legacysim density variations',vmin=0,vmax=2,path=filename)

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

dens = HealpixDensity(map=map)
#dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data,key_weight='WEIGHT')

legacysim_dens = HealpixDensity(map=map)
#legacysim_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)

others = [legacysim_dens]
labels = ['DR9','legacysim']

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'adematti_density_{}.png'.format(run))
#fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000193.22 ]: 06-05 16:35  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000193.46 ]: 06-05 16:35  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000193.47 ]: 06-05 16:35  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000193.47 ]: 06-05 16:35  HealpixDensity  INFO     Found 13674 bricks with randoms.
# [ 000193.53 ]: 06-05 16:35  Utils           INFO     Saving figure to /global/homes/a/arosado/legacysim_runs/DA02/plots/adematti_footprint_north.png.
# [ 000194.13 ]: 06-05 16:36  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000194.21 ]: 06-05 16:36  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000194.22 ]: 06-05 16:36  HealpixDensity  INFO     Found 12693 bricks with randoms.
# [ 000194.23 ]: 06-05 16:36  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000194.24 ]: 06-05 16:36  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000194.24 ]: 06-05 16:36  HealpixDensity  INFO     Found 13674 bricks with randoms.
# [ 000194.35 ]: 06-05 16:36  Properties      INFO     Calculating EBV statistics.
# [ 000194.40 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0199.
# [ 000194.40 ]: 06-05 16:36  Properties      INFO     Calculating EBV statistics.
# [ 000194.44 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0201.
# [ 000194.45 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000194.49 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0131.
# [ 000194.50 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000194.54 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0140.
# [ 000194.54 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000194.58 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0139.
# [ 000194.59 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000194.63 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0135.
# [ 000194.63 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000194.68 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0170.
# [ 000194.68 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000194.72 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0170.
# [ 000194.72 ]: 06-05 16:36  Properties      INFO     Calculating STARDENS statistics.
# [ 000194.77 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0161.
# [ 000194.77 ]: 06-05 16:36  Properties      INFO     Calculating STARDENS statistics.
# [ 000194.81 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0158.
# [ 000194.82 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000194.86 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0170.
# [ 000194.87 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000194.91 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0168.
# [ 000194.91 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000194.96 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0197.
# [ 000194.96 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000195.00 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0183.
# [ 000195.01 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000195.05 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0202.
# [ 000195.06 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000195.10 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0200.

# %%
ax = plt.gca()
ax.hist(legacysim['INPUT_SERSIC'], histtype='step', label='input', density=True)
ax.hist(legacysim['SERSIC'], histtype='step', label='output', density=True)
ax.hist(legacysim_data['SERSIC'], histtype='step', label='selected', density=True)
#ax.hist(data['SERSIC'], histtype='step', label='in data', density=True)
ax.legend()

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

others = []
labels = []
for sersic in [0, 1, 4]:
    legacysim_dens = HealpixDensity(map=map)
    #legacysim_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
    legacysim_dens.set_randoms(randoms=legacysim_randoms[legacysim_randoms['INPUT_SERSIC'] == sersic])
    legacysim_dens.set_properties()
    legacysim_dens.set_data(data=legacysim_data[legacysim_data['INPUT_SERSIC'] == sersic])
    others.append(legacysim_dens)
    labels.append('$n = {:d}$'.format(sersic))

dens, others = others[0], others[1:]

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'adematti_density_{}.png'.format(run))
#fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000215.21 ]: 06-05 16:36  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000215.29 ]: 06-05 16:36  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000215.48 ]: 06-05 16:36  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000215.48 ]: 06-05 16:36  HealpixDensity  INFO     Found 11296 bricks with randoms.
# [ 000215.69 ]: 06-05 16:36  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000215.91 ]: 06-05 16:36  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000215.92 ]: 06-05 16:36  HealpixDensity  INFO     Found 13538 bricks with randoms.
# [ 000216.17 ]: 06-05 16:36  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000216.26 ]: 06-05 16:36  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000216.26 ]: 06-05 16:36  HealpixDensity  INFO     Found 9146 bricks with randoms.
# [ 000216.46 ]: 06-05 16:36  Properties      INFO     Calculating EBV statistics.
# [ 000216.50 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0203.
# [ 000216.50 ]: 06-05 16:36  Properties      INFO     Calculating EBV statistics.
# [ 000216.55 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0200.
# [ 000216.55 ]: 06-05 16:36  Properties      INFO     Calculating EBV statistics.
# [ 000216.59 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0201.
# [ 000216.60 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000216.64 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0189.
# [ 000216.64 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000216.69 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0196.
# [ 000216.69 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000216.73 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0194.
# [ 000216.73 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000216.78 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0184.
# [ 000216.79 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000216.84 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0195.
# [ 000216.85 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000216.89 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0192.
# [ 000216.89 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000216.93 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0197.
# [ 000216.94 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000216.98 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0209.
# [ 000216.98 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000217.02 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0172.
# [ 000217.03 ]: 06-05 16:36  Properties      INFO     Calculating STARDENS statistics.
# [ 000217.07 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0158.
# [ 000217.07 ]: 06-05 16:36  Properties      INFO     Calculating STARDENS statistics.
# [ 000217.12 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0166.
# [ 000217.12 ]: 06-05 16:36  Properties      INFO     Calculating STARDENS statistics.
# [ 000217.16 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0153.
# [ 000217.16 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000217.21 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0195.
# [ 000217.21 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000217.26 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0205.
# [ 000217.26 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000217.30 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0179.
# [ 000217.30 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000217.35 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0204.
# [ 000217.35 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000217.39 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0198.
# [ 000217.40 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000217.44 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0175.
# [ 000217.44 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000217.49 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0195.
# [ 000217.49 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000217.53 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0223.
# [ 000217.53 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000217.57 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0199.

# %%
from photometry import Catalogue, HealpixDensity

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

dens = HealpixDensity(map=map)
#dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data,key_weight='WEIGHT')

others = []
labels = ['DR9']

for sersic in [None, 1]:
    legacysim_dens = HealpixDensity(map=map)
    #legacysim_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
    if sersic is not None:
        legacysim_dens.set_randoms(randoms=legacysim_randoms[legacysim_randoms['INPUT_SERSIC'] == sersic])
    else:
        legacysim_dens.set_randoms(randoms=legacysim_randoms)
    legacysim_dens.set_properties()
    if sersic is not None:
        legacysim_dens.set_data(data=legacysim_data[legacysim_data['INPUT_SERSIC'] == sersic])
    else:
        legacysim_dens.set_data(data=legacysim_data)
    others.append(legacysim_dens)
    labels.append('legacysim' if sersic is None else 'legacysim $n = {:d}$'.format(sersic))

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'adematti_density_{}.png'.format(run))
#fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000229.67 ]: 06-05 16:36  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000229.74 ]: 06-05 16:36  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000229.75 ]: 06-05 16:36  HealpixDensity  INFO     Found 12693 bricks with randoms.
# [ 000229.76 ]: 06-05 16:36  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000229.77 ]: 06-05 16:36  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000229.77 ]: 06-05 16:36  HealpixDensity  INFO     Found 13674 bricks with randoms.
# [ 000229.81 ]: 06-05 16:36  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000230.10 ]: 06-05 16:36  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000230.10 ]: 06-05 16:36  HealpixDensity  INFO     Found 13538 bricks with randoms.
# [ 000230.59 ]: 06-05 16:36  Properties      INFO     Calculating EBV statistics.
# [ 000230.66 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0199.
# [ 000230.66 ]: 06-05 16:36  Properties      INFO     Calculating EBV statistics.
# [ 000230.71 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0201.
# [ 000230.71 ]: 06-05 16:36  Properties      INFO     Calculating EBV statistics.
# [ 000230.75 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0198.
# [ 000230.76 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000230.81 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0131.
# [ 000230.81 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000230.85 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0140.
# [ 000230.85 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000230.90 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0140.
# [ 000230.90 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000230.95 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0139.
# [ 000230.95 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000230.99 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0135.
# [ 000231.00 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000231.04 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0135.
# [ 000231.04 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000231.11 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0170.
# [ 000231.11 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000231.15 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0170.
# [ 000231.16 ]: 06-05 16:36  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000231.20 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0169.
# [ 000231.21 ]: 06-05 16:36  Properties      INFO     Calculating STARDENS statistics.
# [ 000231.25 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0161.
# [ 000231.25 ]: 06-05 16:36  Properties      INFO     Calculating STARDENS statistics.
# [ 000231.30 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0158.
# [ 000231.30 ]: 06-05 16:36  Properties      INFO     Calculating STARDENS statistics.
# [ 000231.35 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0157.
# [ 000231.35 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000231.40 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0170.
# [ 000231.40 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000231.44 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0168.
# [ 000231.45 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000231.49 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0172.
# [ 000231.49 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000231.54 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0197.
# [ 000231.54 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000231.58 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0183.
# [ 000231.59 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000231.63 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000231.63 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000231.67 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0202.
# [ 000231.68 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000231.72 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0200.
# [ 000231.72 ]: 06-05 16:36  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000231.77 ]: 06-05 16:36  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0199.

# %% [markdown]
# # TEST CODE

# %%
dens

# %%
# Step 1
import pickle
 
# Step 2
with open('adematti_dens_concat', 'wb') as density_variation_file:
 
  # Step 3
    pickle.dump(dens, density_variation_file)

# %%
# Step 1
import pickle
 
# Step 2
with open('adematti_dens_concat', 'rb') as density_variation_file:
 
    # Step 3
    adematti_dens = pickle.load(density_variation_file)
 
    # After adematti_dens is read from file
    print(adematti_dens)
# Out:
# <photometry.density_variations.HealpixDensity object at 0x15551e63c190>

# %%
others
# Out:
# [<photometry.density_variations.HealpixDensity at 0x15552464f1f0>,
#  <photometry.density_variations.HealpixDensity at 0x1555243e0ee0>]

# %%
# Step 1
import pickle
 
# Step 2
with open('adematti_others_concat', 'wb') as others_file:
 
  # Step 3
    pickle.dump(others, others_file)

# %%
# Step 1
import pickle
 
# Step 2
with open('adematti_others_concat', 'rb') as others_file:
 
    # Step 3
    adematti_others = pickle.load(others_file)
 
    # After adematti_dens is read from file
    print(adematti_others)
# Out:
# [<photometry.density_variations.HealpixDensity object at 0x15552461f1f0>, <photometry.density_variations.HealpixDensity object at 0x155524630f10>]

# %%
fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
    adematti_dens.plot_density_variations(ax=lax[iax],others=adematti_others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'adematti_density_{}.png'.format(run))
#fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000274.27 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0199.
# [ 000274.28 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0201.
# [ 000274.28 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0198.
# [ 000274.29 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0199.
# [ 000274.30 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0201.
# [ 000274.30 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0198.
# [ 000274.32 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0131.
# [ 000274.32 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0140.
# [ 000274.33 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0140.
# [ 000274.34 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0131.
# [ 000274.34 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0140.
# [ 000274.35 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0140.
# [ 000274.36 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0139.
# [ 000274.36 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0135.
# [ 000274.37 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0135.
# [ 000274.38 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0139.
# [ 000274.48 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0135.
# [ 000274.48 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0135.
# [ 000274.49 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0170.
# [ 000274.50 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0170.
# [ 000274.50 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0169.
# [ 000274.51 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0170.
# [ 000274.51 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0170.
# [ 000274.52 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0169.
# [ 000274.53 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0161.
# [ 000274.53 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0158.
# [ 000274.53 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0157.
# [ 000274.54 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0161.
# [ 000274.55 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0158.
# [ 000274.55 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0157.
# [ 000274.56 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0170.
# [ 000274.56 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0168.
# [ 000274.57 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0172.
# [ 000274.57 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0170.
# [ 000274.58 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0168.
# [ 000274.58 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0172.
# [ 000274.59 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0197.
# [ 000274.60 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0183.
# [ 000274.60 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000274.61 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0197.
# [ 000274.61 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0183.
# [ 000274.62 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000274.63 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0202.
# [ 000274.63 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0200.
# [ 000274.63 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0199.
# [ 000274.64 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0202.
# [ 000274.65 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0200.
# [ 000274.65 ]: 06-05 16:37  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0199.
