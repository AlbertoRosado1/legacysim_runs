# %%
import sys
sys.path.append("/global/homes/a/arosado/photometry/")

# %%
import os
import logging
import numpy as np
import fitsio as ft
from matplotlib import pyplot as plt

from photometry import TargetSelection, utils, setup_logging

# %% [markdown]
# I used `ELGzdone_full_noveto.dat.fits` while Arnaud used `ELGzdone_full.dat.fits`

# %%
import os
import logging
import numpy as np
import fitsio as ft
from matplotlib import pyplot as plt

from photometry import TargetSelection, utils, setup_logging

logger = logging.getLogger('DA02')
setup_logging()

plot_dir = '/global/homes/a/arosado/legacysim_runs/DA02/plots'
run = 'north'
region = run[0].upper()
base_dir = '/global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2'
data_fn = os.path.join(base_dir, 'ELGzdone_full_noveto.dat.fits')
randoms_fn = os.path.join(base_dir, 'ELGzdone_0_full_noveto.ran.fits')
hp_fn = '/global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits'
legacysim_fn = os.path.join(os.getenv('CSCRATCH'),'legacysim','dr9','DA02',run,'file0_rs0_skip0','merged','matched_input.fits')
logger.info('Filename: {}'.format(legacysim_fn))
# Out:
# [ 000000.00 ]: 05-03 16:14  DA02            INFO     Filename: /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/matched_input.fits

# %%
adematti_base_dir = '/global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/everest/LSScats/1.1'
adematti_data_fn = os.path.join(base_dir, 'ELGzdone_full.dat.fits')
adematti_randoms_fn = os.path.join(base_dir, 'ELGzdone_0_full.ran.fits')
adematti_legacysim_fn = os.path.join(os.getenv('CSCRATCH'),'legacysim','dr9','DA02',run,'file0_rs0_skip0','merged','adematti_matched_input.fits')
logger.info('Filename: {}'.format(adematti_legacysim_fn))
# Out:
# [ 000000.97 ]: 05-03 16:14  DA02            INFO     Filename: /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/adematti_matched_input.fits

# %% [markdown]
# # Functions

# %%
def isELG_colors(gflux=None, rflux=None, zflux=None, w1flux=None,
                 w2flux=None, gfiberflux=None, south=True, primary=None,
                 gmarg=0., grmarg=0., rzmarg=0.):
    """
    Apply ELG selection with box enlarged by ``gmarg``, ``grmarg``, ``rzmarg``.

    SV3 selection from https://github.com/desihub/desitarget/blob/7786db0931d23ed20de7ef37a6f07a52072e11ab/py/desitarget/sv3/sv3_cuts.py#L526
    """
    if primary is None:
        primary = np.ones_like(rflux, dtype='?')
    elg = primary.copy()

    # ADM work in magnitudes instead of fluxes. NOTE THIS IS ONLY OK AS
    # ADM the snr masking in ALL OF g, r AND z ENSURES positive fluxes.
    g = 22.5 - 2.5*np.log10(gflux.clip(1e-16))
    r = 22.5 - 2.5*np.log10(rflux.clip(1e-16))
    z = 22.5 - 2.5*np.log10(zflux.clip(1e-16))
    gfib = 22.5 - 2.5*np.log10(gfiberflux.clip(1e-16))

    # ADM cuts shared by the northern and southern selections.
    elg &= g > 20 - gmarg                # bright cut.
    elg &= r - z > 0.15 - rzmarg         # blue cut.
#    elg &= r - z < 1.6 + rzmarg         # red cut.

    # ADM cuts that are unique to the north or south. Identical for sv3
    # ADM but keep the north/south formalism in case we use it later.
    if south:
        elg &= gfib < 24.1 + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.
    else:
        elg &= gfib < 24. + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.

    # ADM separate a low-priority and a regular sample.
    elgvlo = elg.copy()

    # ADM low-priority OII flux cut.
    elgvlo &= g - r < -1.2*(r - z) + 1.6 + grmarg
    elgvlo &= g - r >= -1.2*(r - z) + 1.3 - grmarg

    # ADM high-priority OII flux cut.
    elg &= g - r < -1.2*(r - z) + 1.3 + grmarg

    return elgvlo, elg


def mask_ts(self,key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region,gmarg=0.,grmarg=0.,rzmarg=0.,gcut=-np.inf):
    mask = isELG_colors(gflux=self['{}_G'.format(key_flux)],rflux=self['{}_R'.format(key_flux)],
                        zflux=self['{}_Z'.format(key_flux)],gfiberflux=self['{}_G'.format(key_fiberflux)],south=region=='S',
                        gmarg=gmarg,grmarg=grmarg,rzmarg=rzmarg)
    mask = mask[0] | mask[1]
    mask &= self['{}_G'.format(key_flux)] > gcut
    return mask

TargetSelection.mask_ts = mask_ts

# %% [markdown]
# # Code

# %% [markdown]
# Get bricks that are same for both runs

# %%
my_bricks = np.unique(ft.FITS(legacysim_fn)[1]['input_brickname'][:])
adematti_bricks = np.unique(ft.FITS(adematti_legacysim_fn)[1]['input_brickname'][:])
mask = np.isin(adematti_bricks, my_bricks)
bricks2use = adematti_bricks[mask]
bricks2use.size
# Out:
# 7685

# %% [markdown]
# My Results (only choose bricks in Arnaud's set)

# %%
# legacysim
legacysim = TargetSelection.load_objects(legacysim_fn, radecbox=None, tracer='ELG', region=None)
legacysim.set_upper_case()

# here we select only the bricks I ran
compare_mask = np.isin(legacysim['INPUT_BRICKNAME'], bricks2use)
legacysim = legacysim[compare_mask]

#continue the same as always
legacysim['RA'] = legacysim['INPUT_RA']
legacysim['DEC'] = legacysim['INPUT_DEC']
#legacysim['MATCHED'] = legacysim['DISTANCE'] < 0.15/3600.
logger.info('Found {:d}/{:d} matches.'.format(legacysim['MATCHED'].sum(),legacysim.size))
for b in legacysim.bands:
    legacysim['INPUT_EFLUX_{}'.format(b)] = utils.mag_to_flux(legacysim['INPUT_{}'.format(b)])
legacysim['INPUT_EFIBERFLUX_G'] = utils.mag_to_flux(legacysim['INPUT_GFIBER'])
legacysim.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
legacysim['EFIBERFLUX_G'] = legacysim.estimated_flux('G',key_transmission='MW_TRANSMISSION',key_flux='FIBERFLUX')
mask_tsin = legacysim.mask_ts(key_flux='INPUT_EFLUX',key_fiberflux='INPUT_EFIBERFLUX',region=region)
#mask_tsin &= legacysim.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
mask_tsout = legacysim.mask_ts(key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region) & legacysim['MATCHED']
#mask_tsout &= legacysim.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
logger.info('Selecting {:d} (output)/{:d} (input) injected sources.'.format(mask_tsout.sum(),mask_tsin.sum()))
legacysim_data = legacysim[mask_tsout]
legacysim_randoms = legacysim[mask_tsin]
# Out:
# [ 000029.24 ]: 05-03 16:14  Catalogue       INFO     Loading catalogue /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/matched_input.fits.
# [ 000046.95 ]: 05-03 16:15  TargetSelection INFO     Selecting 4222391/4222391 targets.
# [ 000070.79 ]: 05-03 16:15  DA02            INFO     Found 2883278/4153756 matches.
# [ 000072.92 ]: 05-03 16:15  DA02            INFO     Selecting 158118 (output)/132085 (input) injected sources.

# %%
np.unique(legacysim['INPUT_BRICKNAME']).size
# Out:
# 7685

# %% [markdown]
# ## plotting my data

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)
legacysim_dens = HealpixDensity(map=map)
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)
filename = os.path.join(plot_dir,'footprint_{}.png'.format(run))
legacysim_dens.plot_density_map(title='legacysim density variations',vmin=0,vmax=2)
# Out:
# [ 000150.51 ]: 05-03 16:16  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000150.66 ]: 05-03 16:16  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000150.67 ]: 05-03 16:16  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000150.68 ]: 05-03 16:16  HealpixDensity  INFO     Found 10142 bricks with randoms.

# %%
spectro = True

def mask_data_zok(data, dchi2=0.9, tsnrcut=80):
    mask = data['o2c'] > dchi2
    mask &= data['ZWARN']*0 == 0
    mask &= data['ZWARN'] != 999999
    mask &= data['LOCATION_ASSIGNED'] == 1
    mask &= data['TSNR2_ELG'] > tsnrcut
    return mask

def mask_randoms_zok(randoms, tsnrcut=80):
    mask = randoms['TSNR2_ELG'] > tsnrcut
    return mask

# ELG targets, TS applied already
bricknames = np.unique(legacysim['BRICKNAME'])
logger.info('Found {:d} bricknames'.format(bricknames.size))
data = TargetSelection.load_objects(data_fn,region=region)

mask = np.in1d(data['BRICKNAME'],bricknames)
#mask[:] = True # do not cut data on the same bricks as legacysim
data.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
data['EFIBERFLUX_G'] = data.estimated_flux('G',key_transmission='MW_TRANSMISSION',key_flux='FIBERFLUX')
data.set_mag_from_flux(key_flux='EFLUX')

mask &= data.mask_ts(key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region)
#mask &= data.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
if spectro: mask &= mask_data_zok(data)
data['WEIGHT'] = data.ones()
nreal = 128
#nassign = nreal*data['PROB_OBS'] + 1. #assignment in actual observation counts
#if spectro: data['WEIGHT'] *= (nreal+1)/nassign
if spectro: data['WEIGHT'] *= 1/data['FRACZ_TILELOCID']
logger.info('Selecting {:d}/{:d} targets.'.format(mask.sum(), mask.size))
data = data[mask]

randoms = TargetSelection.load_objects(randoms_fn,region=region)
from desiutil.brick import Bricks
randoms['BRICKNAME'] = Bricks().brickname(randoms['RA'], randoms['DEC'])

mask = np.in1d(randoms['BRICKNAME'],bricknames)
#mask[:] = True
#mask &= randoms.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
if spectro: mask &= mask_randoms_zok(randoms)
randoms = randoms[mask]

def from_map(cat, fields):
    import healpy as hp
    map = Catalogue.load(hp_fn)
    theta,phi = utils.radec_to_thphi(cat['RA'],cat['DEC'])
    hppix = hp.ang2pix(map.header['HPXNSIDE'],theta,phi,nest=map.header['HPXNEST'],lonlat=False)
    for field in fields: cat[field] = map[field][hppix]
# Out:
# [ 000188.88 ]: 05-03 16:17  DA02            INFO     Found 7686 bricknames
# [ 000188.88 ]: 05-03 16:17  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2/ELGzdone_full_noveto.dat.fits.
# [ 000206.46 ]: 05-03 16:17  TargetSelection INFO     Selecting 1388368/4424177 targets.
# <ipython-input-10-f1bb1b9a7c97>:33: RuntimeWarning: divide by zero encountered in true_divide
#   if spectro: data['WEIGHT'] *= 1/data['FRACZ_TILELOCID']
# [ 000210.99 ]: 05-03 16:17  DA02            INFO     Selecting 46876/1388368 targets.
# [ 000211.25 ]: 05-03 16:17  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2/ELGzdone_0_full_noveto.ran.fits.
# [ 000217.61 ]: 05-03 16:17  TargetSelection INFO     Selecting 1423842/4471075 targets.

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)
legacysim_dens = HealpixDensity(map=map)
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)
filename = os.path.join(plot_dir,'footprint_{}.png'.format(run))
legacysim_dens.plot_density_map(title='legacysim density variations',vmin=0,vmax=2,path=filename)

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

dens = HealpixDensity(map=map)
#dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data,key_weight='WEIGHT')

legacysim_dens = HealpixDensity(map=map)
#legacysim_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)

others = [legacysim_dens]
labels = ['DR9','legacysim']

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'density_{}.png'.format(run))
#fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000238.96 ]: 05-03 16:18  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000239.06 ]: 05-03 16:18  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000239.09 ]: 05-03 16:18  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000239.09 ]: 05-03 16:18  HealpixDensity  INFO     Found 10142 bricks with randoms.
# [ 000239.14 ]: 05-03 16:18  Utils           INFO     Saving figure to /global/homes/a/arosado/legacysim_runs/DA02/plots/footprint_north.png.
# [ 000239.78 ]: 05-03 16:18  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000239.84 ]: 05-03 16:18  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000239.84 ]: 05-03 16:18  HealpixDensity  INFO     Found 9438 bricks with randoms.
# [ 000239.85 ]: 05-03 16:18  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000239.86 ]: 05-03 16:18  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000239.86 ]: 05-03 16:18  HealpixDensity  INFO     Found 10142 bricks with randoms.
# [ 000240.00 ]: 05-03 16:18  Properties      INFO     Calculating EBV statistics.
# [ 000240.04 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0193.
# [ 000240.04 ]: 05-03 16:18  Properties      INFO     Calculating EBV statistics.
# [ 000240.09 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0199.
# [ 000240.10 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000240.14 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0137.
# [ 000240.15 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000240.21 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0150.
# [ 000240.21 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000240.25 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0142.
# [ 000240.26 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000240.30 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0147.
# [ 000240.31 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000240.35 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0173.
# [ 000240.35 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000240.40 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0175.
# [ 000240.40 ]: 05-03 16:18  Properties      INFO     Calculating STARDENS statistics.
# [ 000240.45 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0151.
# [ 000240.45 ]: 05-03 16:18  Properties      INFO     Calculating STARDENS statistics.
# [ 000240.49 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0152.
# [ 000240.50 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000240.54 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0165.
# [ 000240.55 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000240.59 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0172.
# [ 000240.60 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000240.64 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0187.
# [ 000240.64 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000240.69 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000240.69 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000240.75 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0200.
# [ 000240.75 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000240.80 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0201.

# %%
ax = plt.gca()
ax.hist(legacysim['INPUT_SERSIC'], histtype='step', label='input', density=True)
ax.hist(legacysim['SERSIC'], histtype='step', label='output', density=True)
ax.hist(legacysim_data['SERSIC'], histtype='step', label='selected', density=True)
#ax.hist(data['SERSIC'], histtype='step', label='in data', density=True)
ax.legend()

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

others = []
labels = []
for sersic in [0, 1, 4]:
    legacysim_dens = HealpixDensity(map=map)
    #legacysim_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
    legacysim_dens.set_randoms(randoms=legacysim_randoms[legacysim_randoms['INPUT_SERSIC'] == sersic])
    legacysim_dens.set_properties()
    legacysim_dens.set_data(data=legacysim_data[legacysim_data['INPUT_SERSIC'] == sersic])
    others.append(legacysim_dens)
    labels.append('$n = {:d}$'.format(sersic))

dens, others = others[0], others[1:]

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'density_{}.png'.format(run))
#fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000248.98 ]: 05-03 16:18  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000249.03 ]: 05-03 16:18  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000249.18 ]: 05-03 16:18  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000249.18 ]: 05-03 16:18  HealpixDensity  INFO     Found 8385 bricks with randoms.
# [ 000249.36 ]: 05-03 16:18  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000249.53 ]: 05-03 16:18  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000249.53 ]: 05-03 16:18  HealpixDensity  INFO     Found 10031 bricks with randoms.
# [ 000249.78 ]: 05-03 16:18  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000249.90 ]: 05-03 16:18  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000249.90 ]: 05-03 16:18  HealpixDensity  INFO     Found 6850 bricks with randoms.
# [ 000250.19 ]: 05-03 16:18  Properties      INFO     Calculating EBV statistics.
# [ 000250.26 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0199.
# [ 000250.27 ]: 05-03 16:18  Properties      INFO     Calculating EBV statistics.
# [ 000250.31 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0197.
# [ 000250.31 ]: 05-03 16:18  Properties      INFO     Calculating EBV statistics.
# [ 000250.37 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0213.
# [ 000250.38 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000250.44 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0215.
# [ 000250.44 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000250.49 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0188.
# [ 000250.49 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000250.53 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0187.
# [ 000250.54 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000250.58 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0187.
# [ 000250.59 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000250.63 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0196.
# [ 000250.63 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000250.67 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0195.
# [ 000250.68 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000250.74 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0203.
# [ 000250.74 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000250.78 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0211.
# [ 000250.79 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000250.83 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0184.
# [ 000250.83 ]: 05-03 16:18  Properties      INFO     Calculating STARDENS statistics.
# [ 000250.88 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0188.
# [ 000250.88 ]: 05-03 16:18  Properties      INFO     Calculating STARDENS statistics.
# [ 000250.92 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0210.
# [ 000250.93 ]: 05-03 16:18  Properties      INFO     Calculating STARDENS statistics.
# [ 000250.97 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0182.
# [ 000250.97 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000251.02 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0200.
# [ 000251.02 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000251.06 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0203.
# [ 000251.07 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000251.11 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0194.
# [ 000251.12 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000251.16 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0194.
# [ 000251.17 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000251.22 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0214.
# [ 000251.22 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000251.26 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000251.27 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000251.33 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0199.
# [ 000251.34 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000251.38 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0219.
# [ 000251.38 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000251.42 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0164.

# %%
from photometry import Catalogue, HealpixDensity

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

dens = HealpixDensity(map=map)
#dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data,key_weight='WEIGHT')

others = []
labels = ['DR9']

for sersic in [None, 1]:
    legacysim_dens = HealpixDensity(map=map)
    #legacysim_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
    if sersic is not None:
        legacysim_dens.set_randoms(randoms=legacysim_randoms[legacysim_randoms['INPUT_SERSIC'] == sersic])
    else:
        legacysim_dens.set_randoms(randoms=legacysim_randoms)
    legacysim_dens.set_properties()
    if sersic is not None:
        legacysim_dens.set_data(data=legacysim_data[legacysim_data['INPUT_SERSIC'] == sersic])
    else:
        legacysim_dens.set_data(data=legacysim_data)
    others.append(legacysim_dens)
    labels.append('legacysim' if sersic is None else 'legacysim $n = {:d}$'.format(sersic))

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'density_{}.png'.format(run))
#fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000258.50 ]: 05-03 16:18  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000258.57 ]: 05-03 16:18  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000258.57 ]: 05-03 16:18  HealpixDensity  INFO     Found 9438 bricks with randoms.
# [ 000258.58 ]: 05-03 16:18  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000258.59 ]: 05-03 16:18  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000258.59 ]: 05-03 16:18  HealpixDensity  INFO     Found 10142 bricks with randoms.
# [ 000258.61 ]: 05-03 16:18  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000258.88 ]: 05-03 16:18  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000258.89 ]: 05-03 16:18  HealpixDensity  INFO     Found 10031 bricks with randoms.
# [ 000259.32 ]: 05-03 16:18  Properties      INFO     Calculating EBV statistics.
# [ 000259.41 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0193.
# [ 000259.42 ]: 05-03 16:18  Properties      INFO     Calculating EBV statistics.
# [ 000259.48 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0199.
# [ 000259.48 ]: 05-03 16:18  Properties      INFO     Calculating EBV statistics.
# [ 000259.52 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0196.
# [ 000259.53 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000259.58 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0137.
# [ 000259.58 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000259.63 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0150.
# [ 000259.63 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000259.67 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0146.
# [ 000259.68 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000259.72 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0142.
# [ 000259.73 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000259.77 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0147.
# [ 000259.77 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000259.82 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0146.
# [ 000259.82 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000259.87 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0173.
# [ 000259.87 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000259.91 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0175.
# [ 000259.92 ]: 05-03 16:18  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000259.96 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0170.
# [ 000259.97 ]: 05-03 16:18  Properties      INFO     Calculating STARDENS statistics.
# [ 000260.01 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0151.
# [ 000260.02 ]: 05-03 16:18  Properties      INFO     Calculating STARDENS statistics.
# [ 000260.06 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0152.
# [ 000260.06 ]: 05-03 16:18  Properties      INFO     Calculating STARDENS statistics.
# [ 000260.10 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0150.
# [ 000260.11 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000260.16 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0165.
# [ 000260.16 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000260.20 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0172.
# [ 000260.21 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000260.25 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0173.
# [ 000260.25 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000260.30 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0187.
# [ 000260.30 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000260.35 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000260.36 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000260.45 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0179.
# [ 000260.46 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000260.50 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0200.
# [ 000260.51 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000260.55 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0201.
# [ 000260.55 ]: 05-03 16:18  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000260.59 ]: 05-03 16:18  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0204.

# %% [markdown]
# # TEST CODE

# %%
# Step 1
import pickle
 
# Step 2
with open('my_dens', 'wb') as density_variation_file:
 
  # Step 3
    pickle.dump(dens, density_variation_file)

# %%
# Step 1
import pickle
 
# Step 2
with open('my_dens', 'rb') as density_variation_file:
 
    # Step 3
    my_dens = pickle.load(density_variation_file)
 
    # After adematti_dens is read from file
    print(my_dens)
# Out:
# <photometry.density_variations.HealpixDensity object at 0x1555247f01c0>

# %%
# Step 1
import pickle
 
# Step 2
with open('my_others', 'wb') as others_file:
 
  # Step 3
    pickle.dump(others, others_file)

# %%
# Step 1
import pickle
 
# Step 2
with open('my_others', 'rb') as others_file:
 
    # Step 3
    my_others = pickle.load(others_file)
 
    # After adematti_dens is read from file
    print(my_others)
# Out:
# [<photometry.density_variations.HealpixDensity object at 0x1555247f0490>, <photometry.density_variations.HealpixDensity object at 0x15552462aa00>]

# %%
fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
    my_dens.plot_density_variations(ax=lax[iax],others=my_others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'adematti_density_{}.png'.format(run))
#fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000443.43 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0193.
# [ 000443.44 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0199.
# [ 000443.44 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0196.
# [ 000443.45 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0193.
# [ 000443.46 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0199.
# [ 000443.46 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0196.
# [ 000443.48 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0137.
# [ 000443.48 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0150.
# [ 000443.48 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0146.
# [ 000443.49 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0137.
# [ 000443.50 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0150.
# [ 000443.50 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0146.
# [ 000443.51 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0142.
# [ 000443.52 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0147.
# [ 000443.53 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0146.
# [ 000443.53 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0142.
# [ 000443.54 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0147.
# [ 000443.54 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0146.
# [ 000443.55 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0173.
# [ 000443.56 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0175.
# [ 000443.56 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0170.
# [ 000443.57 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0173.
# [ 000443.58 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0175.
# [ 000443.58 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0170.
# [ 000443.59 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0151.
# [ 000443.59 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0152.
# [ 000443.60 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0150.
# [ 000443.61 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0151.
# [ 000443.61 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0152.
# [ 000443.62 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0150.
# [ 000443.63 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0165.
# [ 000443.64 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0172.
# [ 000443.65 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0173.
# [ 000443.66 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0165.
# [ 000443.67 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0172.
# [ 000443.67 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0173.
# [ 000443.69 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0187.
# [ 000443.70 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000443.70 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0179.
# [ 000443.72 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0187.
# [ 000443.72 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000443.73 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0179.
# [ 000443.74 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0200.
# [ 000443.75 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0201.
# [ 000443.75 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0204.
# [ 000443.76 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0200.
# [ 000443.77 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0201.
# [ 000443.77 ]: 05-03 16:21  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0204.

# %%
# Step 1
import pickle
 
# Step 2
with open('poperties', 'wb') as imaging_properties_file:
 
  # Step 3
    pickle.dump(props, imaging_properties_file)

# %%
labels
# Out:
# ['DR9', 'legacysim', 'legacysim $n = 1$']
