# %%
import sys
sys.path.append("/global/homes/a/arosado/photometry/")

# %%
import os
import logging
import numpy as np
import fitsio as ft
from matplotlib import pyplot as plt

from photometry import TargetSelection, utils, setup_logging

# %% [markdown]
# I used `ELGzdone_full_noveto.dat.fits` while Arnaud used `ELGzdone_full.dat.fits`

# %%
import os
import logging
import numpy as np
import fitsio as ft
from matplotlib import pyplot as plt

from photometry import TargetSelection, utils, setup_logging

logger = logging.getLogger('DA02')
setup_logging()

plot_dir = '/global/homes/a/arosado/legacysim_runs/DA02/plots'
run = 'north'
region = run[0].upper()
base_dir = '/global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2'
data_fn = os.path.join(base_dir, 'ELGzdone_full_noveto.dat.fits')
randoms_fn = os.path.join(base_dir, 'ELGzdone_0_full_noveto.ran.fits')
hp_fn = '/global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits'
legacysim_fn = os.path.join(os.getenv('CSCRATCH'),'legacysim','dr9','DA02',run,'file0_rs0_skip0','merged','matched_input.fits')
logger.info('Filename: {}'.format(legacysim_fn))
# Out:
# [ 000000.00 ]: 04-25 10:14  DA02            INFO     Filename: /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/matched_input.fits

# %%
adematti_base_dir = '/global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/everest/LSScats/1.1'
adematti_data_fn = os.path.join(base_dir, 'ELGzdone_full.dat.fits')
adematti_randoms_fn = os.path.join(base_dir, 'ELGzdone_0_full.ran.fits')
adematti_legacysim_fn = os.path.join(os.getenv('CSCRATCH'),'legacysim','dr9','DA02',run,'file0_rs0_skip0','merged','adematti_matched_input.fits')
logger.info('Filename: {}'.format(adematti_legacysim_fn))
# Out:
# [ 000000.01 ]: 04-25 10:14  DA02            INFO     Filename: /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/adematti_matched_input.fits

# %%
def isELG_colors(gflux=None, rflux=None, zflux=None, w1flux=None,
                 w2flux=None, gfiberflux=None, south=True, primary=None,
                 gmarg=0., grmarg=0., rzmarg=0.):
    """
    Apply ELG selection with box enlarged by ``gmarg``, ``grmarg``, ``rzmarg``.

    SV3 selection from https://github.com/desihub/desitarget/blob/7786db0931d23ed20de7ef37a6f07a52072e11ab/py/desitarget/sv3/sv3_cuts.py#L526
    """
    if primary is None:
        primary = np.ones_like(rflux, dtype='?')
    elg = primary.copy()

    # ADM work in magnitudes instead of fluxes. NOTE THIS IS ONLY OK AS
    # ADM the snr masking in ALL OF g, r AND z ENSURES positive fluxes.
    g = 22.5 - 2.5*np.log10(gflux.clip(1e-16))
    r = 22.5 - 2.5*np.log10(rflux.clip(1e-16))
    z = 22.5 - 2.5*np.log10(zflux.clip(1e-16))
    gfib = 22.5 - 2.5*np.log10(gfiberflux.clip(1e-16))

    # ADM cuts shared by the northern and southern selections.
    elg &= g > 20 - gmarg                # bright cut.
    elg &= r - z > 0.15 - rzmarg         # blue cut.
#    elg &= r - z < 1.6 + rzmarg         # red cut.

    # ADM cuts that are unique to the north or south. Identical for sv3
    # ADM but keep the north/south formalism in case we use it later.
    if south:
        elg &= gfib < 24.1 + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.
    else:
        elg &= gfib < 24. + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.

    # ADM separate a low-priority and a regular sample.
    elgvlo = elg.copy()

    # ADM low-priority OII flux cut.
    elgvlo &= g - r < -1.2*(r - z) + 1.6 + grmarg
    elgvlo &= g - r >= -1.2*(r - z) + 1.3 - grmarg

    # ADM high-priority OII flux cut.
    elg &= g - r < -1.2*(r - z) + 1.3 + grmarg

    return elgvlo, elg


def mask_ts(self,key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region,gmarg=0.,grmarg=0.,rzmarg=0.,gcut=-np.inf):
    mask = isELG_colors(gflux=self['{}_G'.format(key_flux)],rflux=self['{}_R'.format(key_flux)],
                        zflux=self['{}_Z'.format(key_flux)],gfiberflux=self['{}_G'.format(key_fiberflux)],south=region=='S',
                        gmarg=gmarg,grmarg=grmarg,rzmarg=rzmarg)
    mask = mask[0] | mask[1]
    mask &= self['{}_G'.format(key_flux)] > gcut
    return mask

TargetSelection.mask_ts = mask_ts

# %% [markdown]
# # Code

# %%
my_bricks = np.unique(ft.FITS(legacysim_fn)[1]['input_brickname'][:])

# %%
my_bricks.size
# Out:
# 7812

# %%
adematti_bricks = np.unique(ft.FITS(adematti_legacysim_fn)[1]['input_brickname'][:])

# %%
adematti_bricks.size
# Out:
# 10347

# %%
mask = np.isin(adematti_bricks, my_bricks)
bricks2use = adematti_bricks[mask]
bricks2use.size
# Out:
# 7685

# %% [markdown]
# # Function

# %%
def isELG_colors(gflux=None, rflux=None, zflux=None, w1flux=None,
                 w2flux=None, gfiberflux=None, south=True, primary=None,
                 gmarg=0., grmarg=0., rzmarg=0.):
    """
    Apply ELG selection with box enlarged by ``gmarg``, ``grmarg``, ``rzmarg``.

    SV3 selection from https://github.com/desihub/desitarget/blob/7786db0931d23ed20de7ef37a6f07a52072e11ab/py/desitarget/sv3/sv3_cuts.py#L526
    """
    if primary is None:
        primary = np.ones_like(rflux, dtype='?')
    elg = primary.copy()

    # ADM work in magnitudes instead of fluxes. NOTE THIS IS ONLY OK AS
    # ADM the snr masking in ALL OF g, r AND z ENSURES positive fluxes.
    g = 22.5 - 2.5*np.log10(gflux.clip(1e-16))
    r = 22.5 - 2.5*np.log10(rflux.clip(1e-16))
    z = 22.5 - 2.5*np.log10(zflux.clip(1e-16))
    gfib = 22.5 - 2.5*np.log10(gfiberflux.clip(1e-16))

    # ADM cuts shared by the northern and southern selections.
    elg &= g > 20 - gmarg                # bright cut.
    elg &= r - z > 0.15 - rzmarg         # blue cut.
#    elg &= r - z < 1.6 + rzmarg         # red cut.

    # ADM cuts that are unique to the north or south. Identical for sv3
    # ADM but keep the north/south formalism in case we use it later.
    if south:
        elg &= gfib < 24.1 + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.
    else:
        elg &= gfib < 24. + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.

    # ADM separate a low-priority and a regular sample.
    elgvlo = elg.copy()

    # ADM low-priority OII flux cut.
    elgvlo &= g - r < -1.2*(r - z) + 1.6 + grmarg
    elgvlo &= g - r >= -1.2*(r - z) + 1.3 - grmarg

    # ADM high-priority OII flux cut.
    elg &= g - r < -1.2*(r - z) + 1.3 + grmarg

    return elgvlo, elg


def mask_ts(self,key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region,gmarg=0.,grmarg=0.,rzmarg=0.,gcut=-np.inf):
    mask = isELG_colors(gflux=self['{}_G'.format(key_flux)],rflux=self['{}_R'.format(key_flux)],
                        zflux=self['{}_Z'.format(key_flux)],gfiberflux=self['{}_G'.format(key_fiberflux)],south=region=='S',
                        gmarg=gmarg,grmarg=grmarg,rzmarg=rzmarg)
    mask = mask[0] | mask[1]
    mask &= self['{}_G'.format(key_flux)] > gcut
    return mask

TargetSelection.mask_ts = mask_ts

# %% [markdown]
# # code

# %% [markdown]
# My Results (only choose bricks in Arnaud's set)

# %%
# legacysim
legacysim = TargetSelection.load_objects(legacysim_fn, radecbox=None, tracer='ELG', region=None)
legacysim.set_upper_case()

# here we select only the bricks I ran
compare_mask = np.isin(legacysim['INPUT_BRICKNAME'], bricks2use)
legacysim = legacysim[compare_mask]

#continue the same as always
legacysim['RA'] = legacysim['INPUT_RA']
legacysim['DEC'] = legacysim['INPUT_DEC']
#legacysim['MATCHED'] = legacysim['DISTANCE'] < 0.15/3600.
logger.info('Found {:d}/{:d} matches.'.format(legacysim['MATCHED'].sum(),legacysim.size))
for b in legacysim.bands:
    legacysim['INPUT_EFLUX_{}'.format(b)] = utils.mag_to_flux(legacysim['INPUT_{}'.format(b)])
legacysim['INPUT_EFIBERFLUX_G'] = utils.mag_to_flux(legacysim['INPUT_GFIBER'])
legacysim.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
legacysim['EFIBERFLUX_G'] = legacysim.estimated_flux('G',key_transmission='MW_TRANSMISSION',key_flux='FIBERFLUX')
mask_tsin = legacysim.mask_ts(key_flux='INPUT_EFLUX',key_fiberflux='INPUT_EFIBERFLUX',region=region)
#mask_tsin &= legacysim.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
mask_tsout = legacysim.mask_ts(key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region) & legacysim['MATCHED']
#mask_tsout &= legacysim.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
logger.info('Selecting {:d} (output)/{:d} (input) injected sources.'.format(mask_tsout.sum(),mask_tsin.sum()))
legacysim_data = legacysim[mask_tsout]
legacysim_randoms = legacysim[mask_tsin]
# Out:
# [ 000014.38 ]: 04-25 10:14  Catalogue       INFO     Loading catalogue /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/matched_input.fits.
# [ 000031.33 ]: 04-25 10:15  TargetSelection INFO     Selecting 4222391/4222391 targets.
# [ 000055.27 ]: 04-25 10:15  DA02            INFO     Found 2883278/4153756 matches.
# [ 000057.40 ]: 04-25 10:15  DA02            INFO     Selecting 158118 (output)/132085 (input) injected sources.

# %%
np.unique(legacysim['INPUT_BRICKNAME']).size
# Out:
# 7685

# %% [markdown]
# # Function

# %%
def isELG_colors(gflux=None, rflux=None, zflux=None, w1flux=None,
                 w2flux=None, gfiberflux=None, south=True, primary=None,
                 gmarg=0., grmarg=0., rzmarg=0.):
    """
    Apply ELG selection with box enlarged by ``gmarg``, ``grmarg``, ``rzmarg``.

    SV3 selection from https://github.com/desihub/desitarget/blob/7786db0931d23ed20de7ef37a6f07a52072e11ab/py/desitarget/sv3/sv3_cuts.py#L526
    """
    if primary is None:
        primary = np.ones_like(rflux, dtype='?')
    elg = primary.copy()

    # ADM work in magnitudes instead of fluxes. NOTE THIS IS ONLY OK AS
    # ADM the snr masking in ALL OF g, r AND z ENSURES positive fluxes.
    g = 22.5 - 2.5*np.log10(gflux.clip(1e-16))
    r = 22.5 - 2.5*np.log10(rflux.clip(1e-16))
    z = 22.5 - 2.5*np.log10(zflux.clip(1e-16))
    gfib = 22.5 - 2.5*np.log10(gfiberflux.clip(1e-16))

    # ADM cuts shared by the northern and southern selections.
    elg &= g > 20 - gmarg                # bright cut.
    elg &= r - z > 0.15 - rzmarg         # blue cut.
#    elg &= r - z < 1.6 + rzmarg         # red cut.

    # ADM cuts that are unique to the north or south. Identical for sv3
    # ADM but keep the north/south formalism in case we use it later.
    if south:
        elg &= gfib < 24.1 + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.
    else:
        elg &= gfib < 24. + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.

    # ADM separate a low-priority and a regular sample.
    elgvlo = elg.copy()

    # ADM low-priority OII flux cut.
    elgvlo &= g - r < -1.2*(r - z) + 1.6 + grmarg
    elgvlo &= g - r >= -1.2*(r - z) + 1.3 - grmarg

    # ADM high-priority OII flux cut.
    elg &= g - r < -1.2*(r - z) + 1.3 + grmarg

    return elgvlo, elg


def mask_ts(self,key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region,gmarg=0.,grmarg=0.,rzmarg=0.,gcut=-np.inf):
    mask = isELG_colors(gflux=self['{}_G'.format(key_flux)],rflux=self['{}_R'.format(key_flux)],
                        zflux=self['{}_Z'.format(key_flux)],gfiberflux=self['{}_G'.format(key_fiberflux)],south=region=='S',
                        gmarg=gmarg,grmarg=grmarg,rzmarg=rzmarg)
    mask = mask[0] | mask[1]
    mask &= self['{}_G'.format(key_flux)] > gcut
    return mask

TargetSelection.mask_ts = mask_ts

# %% [markdown]
# # Code

# %% [markdown]
# Arnaud's Results, but only choose the bricks I ran.

# %%
# adematti_legacysim
adematti_legacysim = TargetSelection.load_objects(adematti_legacysim_fn, radecbox=None, tracer='ELG', region=None)
adematti_legacysim.set_upper_case()

# here we select only the bricks I ran
compare_mask = np.isin(adematti_legacysim['INPUT_BRICKNAME'], bricks2use)
adematti_legacysim = adematti_legacysim[compare_mask]

# continue the same as always
adematti_legacysim['RA'] = adematti_legacysim['INPUT_RA']
adematti_legacysim['DEC'] = adematti_legacysim['INPUT_DEC']
#
logger.info('Found {:d}/{:d} matches.'.format(adematti_legacysim['MATCHED'].sum(),adematti_legacysim.size))
for b in adematti_legacysim.bands:
    adematti_legacysim['INPUT_EFLUX_{}'.format(b)] = utils.mag_to_flux(adematti_legacysim['INPUT_{}'.format(b)])
adematti_legacysim['INPUT_EFIBERFLUX_G'] = utils.mag_to_flux(adematti_legacysim['INPUT_GFIBER'])
adematti_legacysim.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
adematti_legacysim['EFIBERFLUX_G'] = adematti_legacysim.estimated_flux('G',key_transmission='MW_TRANSMISSION',key_flux='FIBERFLUX')
mask_tsin = adematti_legacysim.mask_ts(key_flux='INPUT_EFLUX',key_fiberflux='INPUT_EFIBERFLUX',region=region)
#
mask_tsout = adematti_legacysim.mask_ts(key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region) & adematti_legacysim['MATCHED']
#
logger.info('Selecting {:d} (output)/{:d} (input) injected sources.'.format(mask_tsout.sum(),mask_tsin.sum()))
adematti_legacysim_data = adematti_legacysim[mask_tsout]
adematti_legacysim_randoms = adematti_legacysim[mask_tsin]
# Out:
# [ 000060.33 ]: 04-25 10:15  Catalogue       INFO     Loading catalogue /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/adematti_matched_input.fits.
# [ 000082.19 ]: 04-25 10:15  TargetSelection INFO     Selecting 5592566/5592566 targets.
# [ 000113.93 ]: 04-25 10:16  DA02            INFO     Found 2883122/4153756 matches.
# [ 000115.88 ]: 04-25 10:16  DA02            INFO     Selecting 158417 (output)/132033 (input) injected sources.

# %%
np.unique(adematti_legacysim['INPUT_BRICKNAME']).size
# Out:
# 7685

# %% [markdown]
# ## plotting my data

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)
legacysim_dens = HealpixDensity(map=map)
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)
filename = os.path.join(plot_dir,'footprint_{}.png'.format(run))
legacysim_dens.plot_density_map(title='legacysim density variations',vmin=0,vmax=2)
# Out:
# [ 000146.09 ]: 04-22 14:38  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000146.17 ]: 04-22 14:38  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000146.19 ]: 04-22 14:38  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 
]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0187.
# [ 000467.17 ]: 04-22 14:44  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000467.22 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0193.
# [ 000467.22 ]: 04-22 14:44  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000467.27 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0195.
# [ 000467.27 ]: 04-22 14:44  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000467.33 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0201.
# [ 000467.33 ]: 04-22 14:44  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000467.38 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0209.
# [ 000467.38 ]: 04-22 14:44  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000467.45 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0181.
# [ 000467.46 ]: 04-22 14:44  Properties      INFO     Calculating STARDENS statistics.
# [ 000467.52 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0183.
# [ 000467.53 ]: 04-22 14:44  Properties      INFO     Calculating STARDENS statistics.
# [ 000467.57 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0206.
# [ 000467.58 ]: 04-22 14:44  Properties      INFO     Calculating STARDENS statistics.
# [ 000467.62 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0175.
# [ 000467.63 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000467.67 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0202.
# [ 000467.68 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000467.73 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0207.
# [ 000467.73 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000467.77 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0201.
# [ 000467.78 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000467.83 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0193.
# [ 000467.83 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000467.88 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0216.
# [ 000467.88 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000467.92 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0190.
# [ 000467.93 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000467.97 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0200.
# [ 000467.98 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000468.02 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0219.
# [ 000468.03 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000468.07 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0168.

# %%
from photometry import Catalogue, HealpixDensity

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

dens = HealpixDensity(map=map)
#dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data,key_weight='WEIGHT')

others = []
labels = ['DR9']

for sersic in [None, 1]:
    legacysim_dens = HealpixDensity(map=map)
    #legacysim_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
    if sersic is not None:
        legacysim_dens.set_randoms(randoms=legacysim_randoms[legacysim_randoms['INPUT_SERSIC'] == sersic])
    else:
        legacysim_dens.set_randoms(randoms=legacysim_randoms)
    legacysim_dens.set_properties()
    if sersic is not None:
        legacysim_dens.set_data(data=legacysim_data[legacysim_data['INPUT_SERSIC'] == sersic])
    else:
        legacysim_dens.set_data(data=legacysim_data)
    others.append(legacysim_dens)
    labels.append('legacysim' if sersic is None else 'legacysim $n = {:d}$'.format(sersic))

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'density_{}.png'.format(run))
fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000483.62 ]: 04-22 14:44  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000483.71 ]: 04-22 14:44  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000483.71 ]: 04-22 14:44  HealpixDensity  INFO     Found 8958 bricks with randoms.
# [ 000483.73 ]: 04-22 14:44  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000483.75 ]: 04-22 14:44  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000483.75 ]: 04-22 14:44  HealpixDensity  INFO     Found 9631 bricks with randoms.
# [ 000483.78 ]: 04-22 14:44  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000484.02 ]: 04-22 14:44  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000484.02 ]: 04-22 14:44  HealpixDensity  INFO     Found 9522 bricks with randoms.
# [ 000484.45 ]: 04-22 14:44  Properties      INFO     Calculating EBV statistics.
# [ 000484.53 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0203.
# [ 000484.54 ]: 04-22 14:44  Properties      INFO     Calculating EBV statistics.
# [ 000484.58 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0203.
# [ 000484.58 ]: 04-22 14:44  Properties      INFO     Calculating EBV statistics.
# [ 000484.63 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0199.
# [ 000484.64 ]: 04-22 14:44  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000484.70 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0138.
# [ 000484.71 ]: 04-22 14:44  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000484.77 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0149.
# [ 000484.78 ]: 04-22 14:44  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000484.82 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0145.
# [ 000484.83 ]: 04-22 14:44  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000484.88 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0142.
# [ 000484.88 ]: 04-22 14:44  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000484.93 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0146.
# [ 000484.93 ]: 04-22 14:44  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000484.98 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0146.
# [ 000484.98 ]: 04-22 14:44  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000485.03 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0175.
# [ 000485.04 ]: 04-22 14:44  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000485.08 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0177.
# [ 000485.08 ]: 04-22 14:44  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000485.13 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0172.
# [ 000485.14 ]: 04-22 14:44  Properties      INFO     Calculating STARDENS statistics.
# [ 000485.19 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0164.
# [ 000485.19 ]: 04-22 14:44  Properties      INFO     Calculating STARDENS statistics.
# [ 000485.23 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0169.
# [ 000485.24 ]: 04-22 14:44  Properties      INFO     Calculating STARDENS statistics.
# [ 000485.28 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0167.
# [ 000485.29 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000485.36 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0162.
# [ 000485.36 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000485.43 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0169.
# [ 000485.43 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000485.48 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0171.
# [ 000485.49 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000485.54 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0191.
# [ 000485.54 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000485.59 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000485.59 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000485.64 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0179.
# [ 000485.64 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000485.69 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0202.
# [ 000485.70 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000485.74 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0203.
# [ 000485.74 ]: 04-22 14:44  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000485.79 ]: 04-22 14:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0207.

# %% [markdown]
# ## plotting Arnaud's data

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)
adematti_legacysim_dens = HealpixDensity(map=map)
adematti_legacysim_dens.set_randoms(randoms=adematti_legacysim_randoms)
adematti_legacysim_dens.set_properties()
adematti_legacysim_dens.set_data(data=adematti_legacysim_data)
adematti_filename = os.path.join(plot_dir,'adematti_footprint_{}.png'.format(run))
adematti_legacysim_dens.plot_density_map(title='Arnauds legacysim density variations',vmin=0,vmax=2)
# Out:
# [ 000163.74 ]: 04-22 14:38  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000163.96 ]: 04-22 14:38  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000163.97 ]: 04-22 14:38  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000163.97 ]: 04-22 14:38  HealpixDensity  INFO     Found 9633 bricks with randoms.

# %%
spectro = True

def mask_data_zok(data, dchi2=0.9, tsnrcut=80):
    mask = data['o2c'] > dchi2
    mask &= data['ZWARN']*0 == 0
    mask &= data['ZWARN'] != 999999
    mask &= data['LOCATION_ASSIGNED'] == 1
    mask &= data['TSNR2_ELG'] > tsnrcut
    return mask

def mask_randoms_zok(randoms, tsnrcut=80):
    mask = randoms['TSNR2_ELG'] > tsnrcut
    return mask

# ELG targets, TS applied already
bricknames = np.unique(adematti_legacysim['BRICKNAME'])
logger.info('Found {:d} bricknames'.format(bricknames.size))
data = TargetSelection.load_objects
]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0202.
# [ 001616.48 ]: 04-22 15:03  Properties      INFO     Calculating EBV statistics.
# [ 001616.52 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0206.
# [ 001616.53 ]: 04-22 15:03  Properties      INFO     Calculating EBV statistics.
# [ 001616.59 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0212.
# [ 001616.61 ]: 04-22 15:03  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 001616.67 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0188.
# [ 001616.68 ]: 04-22 15:03  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 001616.74 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0195.
# [ 001616.75 ]: 04-22 15:03  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 001616.80 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0215.
# [ 001616.81 ]: 04-22 15:03  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 001616.86 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0185.
# [ 001616.86 ]: 04-22 15:03  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 001616.91 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0198.
# [ 001616.91 ]: 04-22 15:03  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 001616.96 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0193.
# [ 001616.96 ]: 04-22 15:03  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 001617.01 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0201.
# [ 001617.01 ]: 04-22 15:03  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 001617.06 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0205.
# [ 001617.06 ]: 04-22 15:03  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 001617.11 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0162.
# [ 001617.11 ]: 04-22 15:03  Properties      INFO     Calculating STARDENS statistics.
# [ 001617.16 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0156.
# [ 001617.16 ]: 04-22 15:03  Properties      INFO     Calculating STARDENS statistics.
# [ 001617.21 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0165.
# [ 001617.21 ]: 04-22 15:03  Properties      INFO     Calculating STARDENS statistics.
# [ 001617.26 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0134.
# [ 001617.26 ]: 04-22 15:03  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 001617.31 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0188.
# [ 001617.31 ]: 04-22 15:03  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 001617.36 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0205.
# [ 001617.36 ]: 04-22 15:03  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 001617.40 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0175.
# [ 001617.41 ]: 04-22 15:03  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 001617.46 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0191.
# [ 001617.46 ]: 04-22 15:03  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 001617.51 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0200.
# [ 001617.53 ]: 04-22 15:03  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 001617.59 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0182.
# [ 001617.59 ]: 04-22 15:03  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 001617.64 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0200.
# [ 001617.64 ]: 04-22 15:03  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 001617.69 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0214.
# [ 001617.69 ]: 04-22 15:03  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 001617.73 ]: 04-22 15:03  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0189.

# %%
from photometry import Catalogue, HealpixDensity

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

dens = HealpixDensity(map=map)
#dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data,key_weight='WEIGHT')

others = []
labels = ['DR9']

for sersic in [None, 1]:
    legacysim_dens = HealpixDensity(map=map)
    #legacysim_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
    if sersic is not None:
        legacysim_dens.set_randoms(randoms=adematti_legacysim_randoms[adematti_legacysim_randoms['INPUT_SERSIC'] == sersic])
    else:
        legacysim_dens.set_randoms(randoms=adematti_legacysim_randoms)
    legacysim_dens.set_properties()
    if sersic is not None:
        legacysim_dens.set_data(data=adematti_legacysim_data[adematti_legacysim_data['INPUT_SERSIC'] == sersic])
    else:
        legacysim_dens.set_data(data=adematti_legacysim_data)
    others.append(legacysim_dens)
    labels.append('legacysim' if sersic is None else 'legacysim $n = {:d}$'.format(sersic))

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'adematti_density_{}.png'.format(run))
fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 001719.53 ]: 04-22 15:04  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 001719.57 ]: 04-22 15:04  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 001719.58 ]: 04-22 15:04  HealpixDensity  INFO     Found 8763 bricks with randoms.
# [ 001719.59 ]: 04-22 15:04  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 001719.61 ]: 04-22 15:04  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 001719.61 ]: 04-22 15:04  HealpixDensity  INFO     Found 9633 bricks with randoms.
# [ 001719.64 ]: 04-22 15:04  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 001719.90 ]: 04-22 15:04  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 001719.90 ]: 04-22 15:04  HealpixDensity  INFO     Found 9535 bricks with randoms.
# [ 001720.40 ]: 04-22 15:04  Properties      INFO     Calculating EBV statistics.
# [ 001720.45 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0197.
# [ 001720.45 ]: 04-22 15:04  Properties      INFO     Calculating EBV statistics.
# [ 001720.50 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0199.
# [ 001720.50 ]: 04-22 15:04  Properties      INFO     Calculating EBV statistics.
# [ 001720.54 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0197.
# [ 001720.55 ]: 04-22 15:04  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 001720.60 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0150.
# [ 001720.60 ]: 04-22 15:04  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 001720.65 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0150.
# [ 001720.65 ]: 04-22 15:04  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 001720.70 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0149.
# [ 001720.70 ]: 04-22 15:04  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 001720.75 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0150.
# [ 001720.75 ]: 04-22 15:04  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 001720.80 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0154.
# [ 001720.80 ]: 04-22 15:04  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 001720.85 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0156.
# [ 001720.85 ]: 04-22 15:04  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 001720.90 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0177.
# [ 001720.90 ]: 04-22 15:04  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 001720.95 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0190.
# [ 001720.95 ]: 04-22 15:04  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 001721.00 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0187.
# [ 001721.00 ]: 04-22 15:04  Properties      INFO     Calculating STARDENS statistics.
# [ 001721.05 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0164.
# [ 001721.05 ]: 04-22 15:04  Properties      INFO     Calculating STARDENS statistics.
# [ 001721.10 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0170.
# [ 001721.10 ]: 04-22 15:04  Properties      INFO     Calculating STARDENS statistics.
# [ 001721.15 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0165.
# [ 001721.15 ]: 04-22 15:04  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 001721.20 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0177.
# [ 001721.20 ]: 04-22 15:04  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 001721.25 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0170.
# [ 001721.25 ]: 04-22 15:04  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 001721.30 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0174.
# [ 001721.30 ]: 04-22 15:04  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 001721.35 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0191.
# [ 001721.35 ]: 04-22 15:04  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 001721.40 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0182.
# [ 001721.40 ]: 04-22 15:04  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 001721.45 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0179.
# [ 001721.45 ]: 04-22 15:04  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 001721.50 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0208.
# [ 001721.50 ]: 04-22 15:04  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 001721.55 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0204.
# [ 001721.55 ]: 04-22 15:04  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 001721.60 ]: 04-22 15:04  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0199.
