# %%
import sys
sys.path.append("/global/homes/a/arosado/photometry/")

# %%
H0 = 68*1000/3.26e6/9.4607e15 # 1/s
1 / H0
# Out:
# 4.535570882352941e+17

# %%
30*64/151
# Out:
# 12.71523178807947

# %%
bricks = 10
memory = 12
cores_per_node = 64
nodes = 30

print(f"Nodes needed for {bricks} tasks and {memory}Gb of memory per task: {int(bricks*memory/cores_per_node)} Nodes")
# Out:
# Nodes needed for 10 tasks and 12Gb of memory per task: 1 Nodes

# %%
import os
import logging
import numpy as np
import fitsio as ft
from matplotlib import pyplot as plt

from photometry import TargetSelection, utils, setup_logging

# %%
# to concatenate matched inputs 00 to 13 for north
from astropy.table import Table, vstack
run = 'north'
merged_dir = os.path.join(os.getenv('CSCRATCH'),'legacysim','dr9','DA02',run,'file0_rs0_skip0','merged')
nber_files = 14
file_idx = file_idx = ["%.2d"%i for i in range(nber_files)]
#Read in the fits table you want to append 
# Use Astropy's 'vstack' function
#concat_legacysim = vstack([Table.read(os.path.join(merged_dir,f'matched_inputs_{i}.fits'), format='fits') for i in file_idx])
# Create fits file with new concatenated randoms
#concat_legacysim.write(os.path.join(merged_dir,'matched_inputs_concatenated.fits'), format='fits', overwrite=False)

# %% [markdown]
# I used `ELGzdone_full_noveto.dat.fits` while Arnaud used `ELGzdone_full.dat.fits`

# %%
import os
import logging
import numpy as np
import fitsio as ft
from matplotlib import pyplot as plt

from photometry import TargetSelection, utils, setup_logging

logger = logging.getLogger('DA02')
setup_logging()

plot_dir = '/global/homes/a/arosado/legacysim_runs/DA02/plots'
run = 'north'
region = run[0].upper()
base_dir = '/global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2'
data_fn = os.path.join(base_dir, 'ELGzdone_full_noveto.dat.fits')
randoms_fn = os.path.join(base_dir, 'ELGzdone_0_full_noveto.ran.fits')
hp_fn = '/global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits'
legacysim_fn = os.path.join(os.getenv('CSCRATCH'),'legacysim','dr9','DA02',run,'file0_rs0_skip0','merged','matched_inputs_concatenated.fits')
logger.info('Filename: {}'.format(legacysim_fn))
# Out:
# [ 000000.00 ]: 06-17 16:12  DA02            INFO     Filename: /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/matched_inputs_concatenated.fits

# %% [markdown]
# # Functions

# %%
def isELG_colors(gflux=None, rflux=None, zflux=None, w1flux=None,
                 w2flux=None, gfiberflux=None, south=True, primary=None,
                 gmarg=0., grmarg=0., rzmarg=0.):
    """
    Apply ELG selection with box enlarged by ``gmarg``, ``grmarg``, ``rzmarg``.

    SV3 selection from https://github.com/desihub/desitarget/blob/7786db0931d23ed20de7ef37a6f07a52072e11ab/py/desitarget/sv3/sv3_cuts.py#L526
    """
    if primary is None:
        primary = np.ones_like(rflux, dtype='?')
    elg = primary.copy()

    # ADM work in magnitudes instead of fluxes. NOTE THIS IS ONLY OK AS
    # ADM the snr masking in ALL OF g, r AND z ENSURES positive fluxes.
    g = 22.5 - 2.5*np.log10(gflux.clip(1e-16))
    r = 22.5 - 2.5*np.log10(rflux.clip(1e-16))
    z = 22.5 - 2.5*np.log10(zflux.clip(1e-16))
    gfib = 22.5 - 2.5*np.log10(gfiberflux.clip(1e-16))

    # ADM cuts shared by the northern and southern selections.
    elg &= g > 20 - gmarg                # bright cut.
    elg &= r - z > 0.15 - rzmarg         # blue cut.
#    elg &= r - z < 1.6 + rzmarg         # red cut.

    # ADM cuts that are unique to the north or south. Identical for sv3
    # ADM but keep the north/south formalism in case we use it later.
    if south:
        elg &= gfib < 24.1 + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.
    else:
        elg &= gfib < 24. + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.

    # ADM separate a low-priority and a regular sample.
    elgvlo = elg.copy()

    # ADM low-priority OII flux cut.
    elgvlo &= g - r < -1.2*(r - z) + 1.6 + grmarg
    elgvlo &= g - r >= -1.2*(r - z) + 1.3 - grmarg

    # ADM high-priority OII flux cut.
    elg &= g - r < -1.2*(r - z) + 1.3 + grmarg

    return elgvlo, elg


def mask_ts(self,key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region,gmarg=0.,grmarg=0.,rzmarg=0.,gcut=-np.inf):
    mask = isELG_colors(gflux=self['{}_G'.format(key_flux)],rflux=self['{}_R'.format(key_flux)],
                        zflux=self['{}_Z'.format(key_flux)],gfiberflux=self['{}_G'.format(key_fiberflux)],south=region=='S',
                        gmarg=gmarg,grmarg=grmarg,rzmarg=rzmarg)
    mask = mask[0] | mask[1]
    mask &= self['{}_G'.format(key_flux)] > gcut
    return mask

TargetSelection.mask_ts = mask_ts

# %% [markdown]
# # Code

# %%
# legacysim
legacysim = TargetSelection.load_objects(legacysim_fn, radecbox=None, tracer='ELG', region=None)
legacysim.set_upper_case()

#continue the same as always
legacysim['RA'] = legacysim['INPUT_RA']
legacysim['DEC'] = legacysim['INPUT_DEC']
#legacysim['MATCHED'] = legacysim['DISTANCE'] < 0.15/3600.
logger.info('Found {:d}/{:d} matches.'.format(legacysim['MATCHED'].sum(),legacysim.size))
for b in legacysim.bands:
    legacysim['INPUT_EFLUX_{}'.format(b)] = utils.mag_to_flux(legacysim['INPUT_{}'.format(b)])
legacysim['INPUT_EFIBERFLUX_G'] = utils.mag_to_flux(legacysim['INPUT_GFIBER'])
legacysim.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
legacysim['EFIBERFLUX_G'] = legacysim.estimated_flux('G',key_transmission='MW_TRANSMISSION',key_flux='FIBERFLUX')
mask_tsin = legacysim.mask_ts(key_flux='INPUT_EFLUX',key_fiberflux='INPUT_EFIBERFLUX',region=region)
#mask_tsin &= legacysim.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
mask_tsout = legacysim.mask_ts(key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region) & legacysim['MATCHED']
#mask_tsout &= legacysim.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
logger.info('Selecting {:d} (output)/{:d} (input) injected sources.'.format(mask_tsout.sum(),mask_tsin.sum()))
legacysim_data = legacysim[mask_tsout]
legacysim_randoms = legacysim[mask_tsin]
# Out:
# [ 000007.18 ]: 06-17 16:13  Catalogue       INFO     Loading catalogue /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/matched_inputs_concatenated.fits.
# [ 000045.05 ]: 06-17 16:13  TargetSelection INFO     Selecting 7502692/7502692 targets.

# %%
np.unique(legacysim['INPUT_BRICKNAME']).size

# %% [markdown]
# ## plotting my data

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)
legacysim_dens = HealpixDensity(map=map)
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)
filename = os.path.join(plot_dir,'footprint_{}.png'.format(run))
legacysim_dens.plot_density_map(title='legacysim density variations',vmin=0,vmax=2)

# %%
spectro = True

def mask_data_zok(data, dchi2=0.9, tsnrcut=80):
    mask = data['o2c'] > dchi2
    mask &= data['ZWARN']*0 == 0
    mask &= data['ZWARN'] != 999999
    mask &= data['LOCATION_ASSIGNED'] == 1
    mask &= data['TSNR2_ELG'] > tsnrcut
    return mask

def mask_randoms_zok(randoms, tsnrcut=80):
    mask = randoms['TSNR2_ELG'] > tsnrcut
    return mask

# ELG targets, TS applied already
bricknames = np.unique(legacysim['BRICKNAME'])
logger.info('Found {:d} bricknames'.format(bricknames.size))
data = TargetSelection.load_objects(data_fn,region=region)
#
print(f"zmin {min(data['Z'])}, zmax {max(data['Z'])}") 
#
mask = np.in1d(data['BRICKNAME'],bricknames)
#mask[:] = True # do not cut data on the same bricks as legacysim
data.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
data['EFIBERFLUX_G'] = data.estimated_flux('G',key_transmission='MW_TRANSMISSION',key_flux='FIBERFLUX')
data.set_mag_from_flux(key_flux='EFLUX')

mask &= data.mask_ts(key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region)
#mask &= data.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
if spectro: mask &= mask_data_zok(data)
data['WEIGHT'] = data.ones()
nreal = 128
#nassign = nreal*data['PROB_OBS'] + 1. #assignment in actual observation counts
#if spectro: data['WEIGHT'] *= (nreal+1)/nassign
if spectro: data['WEIGHT'] *= 1/data['FRACZ_TILELOCID']
logger.info('Selecting {:d}/{:d} targets.'.format(mask.sum(), mask.size))
data = data[mask]

randoms = TargetSelection.load_objects(randoms_fn,region=region)
from desiutil.brick import Bricks
randoms['BRICKNAME'] = Bricks().brickname(randoms['RA'], randoms['DEC'])

mask = np.in1d(randoms['BRICKNAME'],bricknames)
#mask[:] = True
#mask &= randoms.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
if spectro: mask &= mask_randoms_zok(randoms)
randoms = randoms[mask]

def from_map(cat, fields):
    import healpy as hp
    map = Catalogue.load(hp_fn)
    theta,phi = utils.radec_to_thphi(cat['RA'],cat['DEC'])
    hppix = hp.ang2pix(map.header['HPXNSIDE'],theta,phi,nest=map.header['HPXNEST'],lonlat=False)
    for field in fields: cat[field] = map[field][hppix]

# %%
print(f"zmin {min(data['Z'])}, zmax {max(data['Z'])}")

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)
legacysim_dens = HealpixDensity(map=map)
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)
filename = os.path.join(plot_dir,'footprint_{}.png'.format(run))
legacysim_dens.plot_density_map(title='legacysim density variations',vmin=0,vmax=2,path=filename)

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

dens = HealpixDensity(map=map)
#dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data,key_weight='WEIGHT')

legacysim_dens = HealpixDensity(map=map)
#legacysim_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)

others = [legacysim_dens]
labels = ['DR9','legacysim']

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'density_{}.png'.format(run))
#fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000263.89 ]: 06-05 16:49  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000263.97 ]: 06-05 16:49  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000263.99 ]: 06-05 16:49  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000263.99 ]: 06-05 16:49  HealpixDensity  INFO     Found 18170 bricks with randoms.
# [ 000264.06 ]: 06-05 16:49  Utils           INFO     Saving figure to /global/homes/a/arosado/legacysim_runs/DA02/plots/footprint_north.png.
# [ 000264.73 ]: 06-05 16:49  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000264.83 ]: 06-05 16:49  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000264.83 ]: 06-05 16:49  HealpixDensity  INFO     Found 16667 bricks with randoms.
# [ 000264.84 ]: 06-05 16:49  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000264.85 ]: 06-05 16:49  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000264.86 ]: 06-05 16:49  HealpixDensity  INFO     Found 18170 bricks with randoms.
# [ 000264.97 ]: 06-05 16:49  Properties      INFO     Calculating EBV statistics.
# [ 000265.03 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0205.
# [ 000265.03 ]: 06-05 16:49  Properties      INFO     Calculating EBV statistics.
# [ 000265.08 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0206.
# [ 000265.08 ]: 06-05 16:49  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000265.13 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0134.
# [ 000265.13 ]: 06-05 16:49  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000265.17 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0153.
# [ 000265.18 ]: 06-05 16:49  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000265.23 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0145.
# [ 000265.23 ]: 06-05 16:49  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000265.28 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0144.
# [ 000265.28 ]: 06-05 16:49  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000265.33 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0180.
# [ 000265.33 ]: 06-05 16:49  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000265.38 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0177.
# [ 000265.38 ]: 06-05 16:49  Properties      INFO     Calculating STARDENS statistics.
# [ 000265.43 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0190.
# [ 000265.43 ]: 06-05 16:49  Properties      INFO     Calculating STARDENS statistics.
# [ 000265.48 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0191.
# [ 000265.48 ]: 06-05 16:49  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000265.53 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0173.
# [ 000265.54 ]: 06-05 16:49  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000265.58 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0181.
# [ 000265.59 ]: 06-05 16:49  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000265.63 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0206.
# [ 000265.64 ]: 06-05 16:49  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000265.68 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0192.
# [ 000265.69 ]: 06-05 16:49  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000265.74 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0202.
# [ 000265.74 ]: 06-05 16:49  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000265.79 ]: 06-05 16:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0197.

# %%
ax = plt.gca()
ax.hist(legacysim['INPUT_SERSIC'], histtype='step', label='input', density=True)
ax.hist(legacysim['SERSIC'], histtype='step', label='output', density=True)
ax.hist(legacysim_data['SERSIC'], histtype='step', label='selected', density=True)
#ax.hist(data['SERSIC'], histtype='step', label='in data', density=True)
ax.legend()

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

others = []
labels = []
for sersic in [0, 1, 4]:
    legacysim_dens = HealpixDensity(map=map)
    #legacysim_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
    legacysim_dens.set_randoms(randoms=legacysim_randoms[legacysim_randoms['INPUT_SERSIC'] == sersic])
    legacysim_dens.set_properties()
    legacysim_dens.set_data(data=legacysim_data[legacysim_data['INPUT_SERSIC'] == sersic])
    others.append(legacysim_dens)
    labels.append('$n = {:d}$'.format(sersic))

dens, others = others[0], others[1:]

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'density_{}.png'.format(run))
#fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000328.34 ]: 06-05 16:50  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000328.46 ]: 06-05 16:50  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000328.70 ]: 06-05 16:50  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000328.71 ]: 06-05 16:50  HealpixDensity  INFO     Found 15123 bricks with randoms.
# [ 000329.00 ]: 06-05 16:50  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000329.36 ]: 06-05 16:50  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000329.36 ]: 06-05 16:50  HealpixDensity  INFO     Found 17986 bricks with randoms.
# [ 000329.72 ]: 06-05 16:50  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000329.85 ]: 06-05 16:50  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000329.85 ]: 06-05 16:50  HealpixDensity  INFO     Found 12316 bricks with randoms.
# [ 000330.09 ]: 06-05 16:50  Properties      INFO     Calculating EBV statistics.
# [ 000330.14 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0194.
# [ 000330.14 ]: 06-05 16:50  Properties      INFO     Calculating EBV statistics.
# [ 000330.19 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0206.
# [ 000330.19 ]: 06-05 16:50  Properties      INFO     Calculating EBV statistics.
# [ 000330.24 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0203.
# [ 000330.24 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000330.29 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0205.
# [ 000330.29 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000330.34 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0191.
# [ 000330.34 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000330.39 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0181.
# [ 000330.39 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000330.44 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0200.
# [ 000330.44 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000330.49 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0198.
# [ 000330.49 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000330.53 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0182.
# [ 000330.54 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000330.58 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0208.
# [ 000330.59 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000330.63 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0212.
# [ 000330.63 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000330.68 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0192.
# [ 000330.68 ]: 06-05 16:50  Properties      INFO     Calculating STARDENS statistics.
# [ 000330.73 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0178.
# [ 000330.73 ]: 06-05 16:50  Properties      INFO     Calculating STARDENS statistics.
# [ 000330.78 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0192.
# [ 000330.78 ]: 06-05 16:50  Properties      INFO     Calculating STARDENS statistics.
# [ 000330.82 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0166.
# [ 000330.83 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000330.87 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0209.
# [ 000330.88 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000330.92 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0203.
# [ 000330.92 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000330.97 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0195.
# [ 000330.97 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000331.02 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0206.
# [ 000331.02 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000331.07 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0208.
# [ 000331.07 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000331.12 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0207.
# [ 000331.13 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000331.18 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0205.
# [ 000331.18 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000331.23 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0229.
# [ 000331.23 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000331.27 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0194.

# %%
from photometry import Catalogue, HealpixDensity

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

dens = HealpixDensity(map=map)
#dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data,key_weight='WEIGHT')

others = []
labels = ['DR9']

for sersic in [None, 1]:
    legacysim_dens = HealpixDensity(map=map)
    #legacysim_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
    if sersic is not None:
        legacysim_dens.set_randoms(randoms=legacysim_randoms[legacysim_randoms['INPUT_SERSIC'] == sersic])
    else:
        legacysim_dens.set_randoms(randoms=legacysim_randoms)
    legacysim_dens.set_properties()
    if sersic is not None:
        legacysim_dens.set_data(data=legacysim_data[legacysim_data['INPUT_SERSIC'] == sersic])
    else:
        legacysim_dens.set_data(data=legacysim_data)
    others.append(legacysim_dens)
    labels.append('legacysim' if sersic is None else 'legacysim $n = {:d}$'.format(sersic))

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'density_{}.png'.format(run))
#fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000354.61 ]: 06-05 16:50  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000354.69 ]: 06-05 16:50  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000354.69 ]: 06-05 16:50  HealpixDensity  INFO     Found 16667 bricks with randoms.
# [ 000354.70 ]: 06-05 16:50  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000354.72 ]: 06-05 16:50  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000354.72 ]: 06-05 16:50  HealpixDensity  INFO     Found 18170 bricks with randoms.
# [ 000354.75 ]: 06-05 16:50  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000355.01 ]: 06-05 16:50  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000355.01 ]: 06-05 16:50  HealpixDensity  INFO     Found 17986 bricks with randoms.
# [ 000355.47 ]: 06-05 16:50  Properties      INFO     Calculating EBV statistics.
# [ 000355.52 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0205.
# [ 000355.52 ]: 06-05 16:50  Properties      INFO     Calculating EBV statistics.
# [ 000355.56 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0206.
# [ 000355.56 ]: 06-05 16:50  Properties      INFO     Calculating EBV statistics.
# [ 000355.60 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0205.
# [ 000355.61 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000355.65 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0134.
# [ 000355.66 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000355.70 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0153.
# [ 000355.70 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000355.74 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0152.
# [ 000355.75 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000355.79 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0145.
# [ 000355.79 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000355.84 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0144.
# [ 000355.84 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000355.88 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0144.
# [ 000355.88 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000355.93 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0180.
# [ 000355.93 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000355.97 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0177.
# [ 000355.97 ]: 06-05 16:50  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000356.01 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0174.
# [ 000356.02 ]: 06-05 16:50  Properties      INFO     Calculating STARDENS statistics.
# [ 000356.06 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0190.
# [ 000356.06 ]: 06-05 16:50  Properties      INFO     Calculating STARDENS statistics.
# [ 000356.10 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0191.
# [ 000356.11 ]: 06-05 16:50  Properties      INFO     Calculating STARDENS statistics.
# [ 000356.15 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0192.
# [ 000356.15 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000356.20 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0173.
# [ 000356.20 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000356.24 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0181.
# [ 000356.25 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000356.29 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0178.
# [ 000356.29 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000356.34 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0206.
# [ 000356.34 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000356.38 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0192.
# [ 000356.38 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000356.43 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0190.
# [ 000356.43 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000356.48 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0202.
# [ 000356.48 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000356.52 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0197.
# [ 000356.53 ]: 06-05 16:50  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000356.57 ]: 06-05 16:50  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0199.

# %% [markdown]
# # TEST CODE

# %%
# Step 1
import pickle
 
# Step 2
with open('my_dens_concat', 'wb') as density_variation_file:
 
  # Step 3
    pickle.dump(dens, density_variation_file)

# %%
# Step 1
import pickle
 
# Step 2
with open('my_dens', 'rb') as density_variation_file:
 
    # Step 3
    my_dens = pickle.load(density_variation_file)
 
    # After adematti_dens is read from file
    print(my_dens)
# Out:
# <photometry.density_variations.HealpixDensity object at 0x15555118ffd0>

# %%
# Step 1
import pickle
 
# Step 2
with open('my_others_concat', 'wb') as others_file:
 
  # Step 3
    pickle.dump(others, others_file)

# %%
# Step 1
import pickle
 
# Step 2
with open('my_others_concat', 'rb') as others_file:
 
    # Step 3
    my_others = pickle.load(others_file)
 
    # After adematti_dens is read from file
    print(my_others)
# Out:
# [<photometry.density_variations.HealpixDensity object at 0x155524b46c70>, <photometry.density_variations.HealpixDensity object at 0x155524ab5970>]

# %%
fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
    my_dens.plot_density_variations(ax=lax[iax],others=my_others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'adematti_density_{}.png'.format(run))
#fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000514.28 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0199.
# [ 000514.29 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0205.
# [ 000514.29 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0207.
# [ 000514.31 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0193.
# [ 000514.32 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0710.
# [ 000514.32 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0713.
# [ 000514.34 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0131.
# [ 000514.34 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0147.
# [ 000514.35 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0143.
# [ 000514.36 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0137.
# [ 000514.36 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0127.
# [ 000514.37 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0123.
# [ 000514.37 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0139.
# [ 000514.38 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0142.
# [ 000514.38 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0142.
# [ 000514.39 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0142.
# [ 000514.40 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0128.
# [ 000514.40 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0126.
# [ 000514.41 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0170.
# [ 000514.41 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0170.
# [ 000514.42 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0166.
# [ 000514.42 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0173.
# [ 000514.43 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0144.
# [ 000514.43 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0140.
# [ 000514.44 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0161.
# [ 000514.45 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0162.
# [ 000514.45 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0164.
# [ 000514.46 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0151.
# [ 000514.46 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.1135.
# [ 000514.46 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.1133.
# [ 000514.47 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0170.
# [ 000514.48 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0175.
# [ 000514.48 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0175.
# [ 000514.49 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0165.
# [ 000514.49 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0165.
# [ 000514.50 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0166.
# [ 000514.51 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0197.
# [ 000514.51 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0187.
# [ 000514.52 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0186.
# [ 000514.53 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0187.
# [ 000514.53 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0198.
# [ 000514.53 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0197.
# [ 000514.54 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0202.
# [ 000514.55 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0205.
# [ 000514.55 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0207.
# [ 000514.56 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0200.
# [ 000514.57 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0192.
# [ 000514.57 ]: 06-05 16:30  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0196.

# %%
# Step 1
import pickle
 
# Step 2
with open('poperties', 'wb') as imaging_properties_file:
 
  # Step 3
    pickle.dump(props, imaging_properties_file)

# %%
labels
# Out:
# ['DR9', 'legacysim', 'legacysim $n = 1$']
