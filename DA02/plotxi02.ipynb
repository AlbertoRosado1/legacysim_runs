# %%
import fitsio
from matplotlib import pyplot as plt
import numpy as np
import os

# %%
njack = '60'
trs = ['ELG_LOPnotqso']#,'QSO','LRG','BGS_BRIGHT']
bsl = [1,2,4,5,10]
dirxi = '/global/cscratch1/sd/arosado/catalogs/DA02/LSS/guadalupe/LSScats/test/smu/'
xit = 'poles'
baotempdir = '/global/homes/a/ajross/code/BAOfit_xs/BAOtemplates/'

# %%
tr = 'ELG_LOPnotqso'
zws = ['0.6_0.8']#,'0.8_1.1','1.1_1.6']
bs = 10
weights = ['','_depthz']
fmt = ['bo', 'rx']
labels = ['default', 'default_depthz']
for zw in zws:
    for i,weight in enumerate(weights):
        fn_txt = dirxi+'xi'+xit+'_'+tr+'_NScomb_'+zw+f'_default{weight}_lin'+str(bs)+'_njack'+njack+'_nran1_split20.txt'
        xi = np.loadtxt(fn_txt).transpose()
        plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt=fmt[i],label=labels[i])
        plt.xlabel('s (Mpc/h)')
        plt.ylabel(r'$s^2\xi_0$')
        plt.minorticks_on()
        plt.title(tr+' '+zw)
        xilin = np.loadtxt(baotempdir+'xi0DESI0.71.04.08.015.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]**2.*xilin[1]*.6,'k-.',label=r'$\xi_{\rm 0}(z=0),bD(z)=\sqrt{0.6},\beta=0.7$')
    plt.legend()
    plt.xlim(0,150)
    plt.ylim(-100,150)
    #plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
    plt.show()
    
    for i,weight in enumerate(weights):
        fn_txt = dirxi+'xi'+xit+'_'+tr+'_NScomb_'+zw+f'_default{weight}_lin'+str(bs)+'_njack'+njack+'_nran1_split20.txt'
        xi = np.loadtxt(fn_txt).transpose()
        plt.errorbar(xi[0],xi[0]*xi[3],xi[0]*xi[6],fmt=fmt[i],label=labels[i])
        plt.xlabel('s (Mpc/h)')
        plt.ylabel(r'$s\xi_2$')
        plt.minorticks_on()
        plt.title(tr+' '+zw)
        xilin = np.loadtxt(baotempdir+'xi2DESI0.71.04.08.015.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]*xilin[1]*.6,'k-.',label=r'$\xi_{\rm 0}(z=0),bD(z)=\sqrt{0.6},\beta=0.7$')
    plt.legend()
    plt.xlim(0,200)
    #plt.ylim(-25,50)
    #plt.savefig(outdir+'xi2'+tr+zw+str(bs)+'.png')
    plt.show()

    for i,weight in enumerate(weights):
        fn_txt = dirxi+'xi'+xit+'_'+tr+'_NScomb_'+zw+f'_default{weight}_lin'+str(bs)+'_njack'+njack+'_nran1_split20.txt'
        xi = np.loadtxt(fn_txt).transpose()
        plt.errorbar(xi[0],xi[0]*xi[4],xi[0]*xi[7],fmt=fmt[i],label=labels[i])
        plt.xlabel('s (Mpc/h)')
        plt.ylabel(r'$s\xi_4$')
        plt.minorticks_on()
        plt.title(tr+' '+zw)
        xilin = np.loadtxt(baotempdir+'xi4DESI0.71.04.08.015.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]*xilin[1]*.6,'k-.',label=r'$\xi_{\rm 0}(z=0),bD(z)=\sqrt{0.6},\beta=0.7$')
    plt.legend()
    plt.xlim(0,200)
    #plt.ylim(-25,50)
    #plt.savefig(outdir+'xi2'+tr+zw+str(bs)+'.png')
    plt.show()

# %%
tr = 'QSO'
zws = ['0.8_1.1','1.1_1.6','1.6_2.1','2.1_3.5','0.8_3.5','0.8_2.1lowz']
betas = [0.46,0.4,0.36,0.3,0.36,0.39]
bs = 10

for zw,beta in zip(zws,betas):
    fn_txt = dirxi+'xi'+xit+'_'+tr+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran1_split20.txt'
    xi = np.loadtxt(fn_txt).transpose()
    plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='go')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s^2\xi_0$')
    plt.minorticks_on()
    plt.title(tr+' '+zw.strip('lowz'))
    xilin = np.loadtxt(baotempdir+'xi0DESI'+str(beta)+'54715.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]**2.*xilin[1]*1.2,'k-.',label=r'$\xi_{\rm 0}(z=0),bD(z)=1.1,\beta$='+str(beta))

    plt.xlim(0,200)
    plt.ylim(-50,75)
    #plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
    plt.show()
    plt.errorbar(xi[0],xi[0]*xi[3],xi[0]*xi[6],fmt='go')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s\xi_2$')
    plt.minorticks_on()
    plt.title(tr+' '+zw.strip('lowz'))
    xilin = np.loadtxt(baotempdir+'xi2DESI'+str(beta)+'54715.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]*xilin[1]*1.2,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=1.1,\beta=$'+str(beta))

    plt.xlim(0,200)
    #plt.ylim(-25,50)
    #plt.savefig(outdir+'xi2'+tr+zw+str(bs)+'.png')
    plt.show()

# %%
tr = 'LRG'
zws = ['0.4_0.6','0.6_0.8','0.8_1.1','0.4_1.1']
bs = 5
for zw in zws:
    fn_txt = dirxi+'xi'+xit+'_'+tr+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran1_split20.txt'
    xi = np.loadtxt(fn_txt).transpose()
    plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='ro')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s^2\xi_0$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'/xi0DESI0.43.04.08.015.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]**2.*xilin[1]*2.1,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    plt.ylim(-50,110)
    #plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
    plt.show()
    plt.errorbar(xi[0],xi[0]*xi[3],xi[0]*xi[6],fmt='ro')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s\xi_2$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'/xi2DESI0.43.04.08.015.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]*xilin[1]*2.1,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    #plt.ylim(-50,100)
    #plt.savefig(outdir+'xi2'+tr+zw+str(bs)+'.png')
    plt.show()

# %%
tr = 'LRG_IFTreciso'
zws = ['0.4_0.6','0.6_0.8','0.8_1.1','0.4_1.1']
bs = 5
for zw in zws:
    fn_txt = dirxi+'recon/xi'+xit+'_'+tr+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran1_split20.txt'
    xi = np.loadtxt(fn_txt).transpose()
    plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='ro')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s^2\xi_0$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi0DESI0.43.03.05.015.01.dat').transpose()
    #os.environ['HOME']+'/code/BAOfit_xs/BAOtemplates/xi0DESI0.4533515.01.dat
    plt.plot(xilin[0],xilin[0]**2.*xilin[1]*2.1,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    plt.ylim(-50,110)
    #plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
    plt.show()
    plt.errorbar(xi[0],xi[0]*xi[3],xi[0]*xi[6],fmt='ro')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s\xi_2$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi2DESI0.43.03.05.015.01.dat').transpose()
    plt.plot(xilin[0],xilin[0]*xilin[1]*2.1,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    #plt.ylim(-50,100)
    #plt.savefig(outdir+'xi2'+tr+zw+str(bs)+'.png')
    plt.show()

# %%
tr = 'LRG'
rec = 'IFTreciso'
fn_txt = dirxi+'xi'+xit+'_'+tr+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran1_split20.txt'
fn_txt_rec = dirxi+'recon/xi'+xit+'_'+tr+'_'+rec+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran1_split20.txt'
xi = np.loadtxt(fn_txt).transpose()
plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='ro',mfc='w',label='pre-rec')
xi = np.loadtxt(fn_txt_rec).transpose()
plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='^',color='firebrick',label='post-rec')

plt.xlabel('s (Mpc/h)')
plt.ylabel(r'$s^2\xi_0$')
plt.minorticks_on()
plt.title(tr+' '+zw)
#xilin = np.loadtxt(os.environ['HOME']+'/code/BAOfit_xs/BAOtemplates/xi0DESI0.43.03.05.015.01.dat').transpose()
#os.environ['HOME']+'/code/BAOfit_xs/BAOtemplates/xi0DESI0.4533515.01.dat
#plt.plot(xilin[0],xilin[0]**2.*xilin[1]*2.1,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

plt.xlim(0,200)
plt.ylim(-50,110)
plt.legend()
#plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
plt.show()

# %%
tr = 'BGS_BRIGHT'
zws = ['0.1_0.3','0.3_0.5','0.1_0.5']
bl = [1.1,1.7,1.5]
xl = [65,95,85]
bs = 5
for zw,b,x in zip(zws,bl,xl):
    fn_txt = dirxi+'xi'+xit+'_'+tr+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran1_split20.txt'
    xi = np.loadtxt(fn_txt).transpose()
    plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='o',color='k',mfc='w')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s^2\xi_0$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi0DESI0.43.06.010.015.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]**2.*xilin[1]*b,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    plt.ylim(-50,x)
    #plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
    plt.show()
    plt.errorbar(xi[0],xi[0]*xi[3],xi[0]*xi[6],fmt='o',color='k',mfc='w')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s\xi_2$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi2DESI0.43.06.010.015.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]*xilin[1]*b,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    #plt.ylim(-50,100)
    #plt.savefig(outdir+'xi2'+tr+zw+str(bs)+'.png')
    plt.show()

# %%
tr = 'BGS_BRIGHT-21.5'
zws = ['0.1_0.3','0.3_0.5','0.1_0.5']
bl = [1.7,1.7,1.7]
xl = [65,95,85]
bs = 5
for zw,b,x in zip(zws,bl,xl):
    fn_txt = dirxi+'xi'+xit+'_'+tr+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran4_split20.txt'
    xi = np.loadtxt(fn_txt).transpose()
    plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='o',color='k',mfc='w')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s^2\xi_0$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi0DESI0.43.06.010.015.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]**2.*xilin[1]*b,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    #plt.ylim(-50,x)
    plt.ylim(-50,100)
    #plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
    plt.show()
    plt.errorbar(xi[0],xi[0]*xi[3],xi[0]*xi[6],fmt='o',color='k',mfc='w')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s\xi_2$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi2DESI0.43.06.010.015.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]*xilin[1]*b,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    #plt.ylim(-50,100)
    #plt.savefig(outdir+'xi2'+tr+zw+str(bs)+'.png')
    plt.show()

# %%
tr = 'BGS_BRIGHT-21.5_MGreciso'
zws = ['0.1_0.3','0.3_0.5','0.1_0.5']
bl = [1.7,1.7,1.7]
xl = [65,95,85]
bs = 5
for zw,b,x in zip(zws,bl,xl):
    fn_txt = dirxi+'recon/xi'+xit+'_'+tr+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran4_split20.txt'
    xi = np.loadtxt(fn_txt).transpose()
    plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='o',color='k',mfc='w')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s^2\xi_0$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi0DESI0.4543515.01.dat').transpose()
    plt.plot(xilin[0],xilin[0]**2.*xilin[1]*b,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    #plt.ylim(-50,x)
    plt.ylim(-50,100)
    #plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
    plt.show()
    plt.errorbar(xi[0],xi[0]*xi[3],xi[0]*xi[6],fmt='o',color='k',mfc='w')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s\xi_2$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi2DESI0.4543515.01.dat').transpose()
    plt.plot(xilin[0],xilin[0]*xilin[1]*b,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    #plt.ylim(-50,100)
    #plt.savefig(outdir+'xi2'+tr+zw+str(bs)+'.png')
    plt.show()

# %%
tr = 'BGS_BRIGHT-21.5_MGrecsym'
zws = ['0.1_0.3','0.3_0.5','0.1_0.5']
bl = [1.7,1.7,1.7]
xl = [65,95,85]
bs = 5
for zw,b,x in zip(zws,bl,xl):
    fn_txt = dirxi+'recon/xi'+xit+'_'+tr+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran4_split20.txt'
    xi = np.loadtxt(fn_txt).transpose()
    plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='o',color='k',mfc='w')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s^2\xi_0$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi0DESI0.4543515.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]**2.*xilin[1]*b,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    #plt.ylim(-50,x)
    plt.ylim(-50,100)
    #plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
    plt.show()
    plt.errorbar(xi[0],xi[0]*xi[3],xi[0]*xi[6],fmt='o',color='k',mfc='w')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s\xi_2$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi2DESI0.4543515.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]*xilin[1]*b,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    #plt.ylim(-50,100)
    #plt.savefig(outdir+'xi2'+tr+zw+str(bs)+'.png')
    plt.show()

# %%
tr = 'BGS_BRIGHT-21.5_IFTreciso'
zws = ['0.1_0.3','0.3_0.5','0.1_0.5']
bl = [1.7,1.7,1.7]
xl = [65,95,85]
bs = 5
for zw,b,x in zip(zws,bl,xl):
    fn_txt = dirxi+'recon/xi'+xit+'_'+tr+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran1_split20.txt'
    xi = np.loadtxt(fn_txt).transpose()
    plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='o',color='k',mfc='w')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s^2\xi_0$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi0DESI0.4543515.01.dat').transpose()
    plt.plot(xilin[0],xilin[0]**2.*xilin[1]*b,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    #plt.ylim(-50,x)
    plt.ylim(-50,100)
    #plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
    plt.show()
    plt.errorbar(xi[0],xi[0]*xi[3],xi[0]*xi[6],fmt='o',color='k',mfc='w')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s\xi_2$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi2DESI0.4543515.01.dat').transpose()
    plt.plot(xilin[0],xilin[0]*xilin[1]*b,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    #plt.ylim(-50,100)
    #plt.savefig(outdir+'xi2'+tr+zw+str(bs)+'.png')
    plt.show()

# %%
tr = 'BGS_BRIGHT-21.5_IFTPreciso'
zws = ['0.1_0.3','0.3_0.5','0.1_0.5']
bl = [1.7,1.7,1.7]
xl = [65,95,85]
bs = 5
for zw,b,x in zip(zws,bl,xl):
    fn_txt = dirxi+'recon/xi'+xit+'_'+tr+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran1_split20.txt'
    xi = np.loadtxt(fn_txt).transpose()
    plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='o',color='k',mfc='w')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s^2\xi_0$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi0DESI0.4543515.01.dat').transpose()
    plt.plot(xilin[0],xilin[0]**2.*xilin[1]*b,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    #plt.ylim(-50,x)
    plt.ylim(-50,100)
    #plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
    plt.show()
    plt.errorbar(xi[0],xi[0]*xi[3],xi[0]*xi[6],fmt='o',color='k',mfc='w')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s\xi_2$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi2DESI0.4543515.01.dat').transpose()
    plt.plot(xilin[0],xilin[0]*xilin[1]*b,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

    plt.xlim(0,200)
    #plt.ylim(-50,100)
    #plt.savefig(outdir+'xi2'+tr+zw+str(bs)+'.png')
    plt.show()

# %%
tr = 'BGS_BRIGHT-21.5'
rec = 'IFTreciso'
zw = '0.1_0.5'
fn_txt = dirxi+'xi'+xit+'_'+tr+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran4_split20.txt'
fn_txt_rec = dirxi+'recon/xi'+xit+'_'+tr+'_'+rec+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran1_split20.txt'
print(fn_txt_rec)
fn_txt_rec2 = '/global/cfs/cdirs/desi/survey/catalogs/edav1/xi/da02/smu/recon/xipoles_BGS_BRIGHT-21.5_IFTreciso_NScomb_'+zw+'_default_depthz_lin4_njack60_nran1_split20.txt'
print(fn_txt_rec2)
xi = np.loadtxt(fn_txt).transpose()
plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='o',color='0.5',mfc='w',label='pre-rec')
xi = np.loadtxt(fn_txt_rec).transpose()
plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='k^',label='post-rec')

plt.xlabel('s (Mpc/h)')
plt.ylabel(r'$s^2\xi_0$')
plt.minorticks_on()
plt.title(tr+' '+zw)
#xilin = np.loadtxt(os.environ['HOME']+'/code/BAOfit_xs/BAOtemplates/xi0DESI0.43.03.05.015.01.dat').transpose()
#os.environ['HOME']+'/code/BAOfit_xs/BAOtemplates/xi0DESI0.4533515.01.dat
#plt.plot(xilin[0],xilin[0]**2.*xilin[1]*2.1,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

plt.xlim(0,200)
plt.ylim(-50,110)
plt.legend()
#plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
plt.show()

fig = plt.figure(figsize=(8, 6), dpi=80)
plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],label='BGS_BRIGHT-21.5 0.1<z<0.5',fmt='o',color='k',mfc='w')
tr = 'LRG'
rec = 'IFTreciso'
zw = '0.4_1.1'
fn_txt_rec = dirxi+'recon/xi'+xit+'_'+tr+'_'+rec+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran1_split20.txt'
xi = np.loadtxt(fn_txt_rec).transpose()
plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='^',color='firebrick',label='LRG 0.4<z<1.1')

plt.xlabel('s (Mpc/h)',size=16)
plt.ylabel(r'$s^2\xi_0$',size=16)
plt.minorticks_on()
plt.title('IFT isotropic reconstruction applied')
xilin = np.loadtxt(baotempdir+'xi0DESI0.4543515.01.dat').transpose()
b = 2.
plt.plot(xilin[0],xilin[0]**2*xilin[1]*b,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

#xilin = np.loadtxt(os.environ['HOME']+'/code/BAOfit_xs/BAOtemplates/xi0DESI0.43.03.05.015.01.dat').transpose()
#os.environ['HOME']+'/code/BAOfit_xs/BAOtemplates/xi0DESI0.4533515.01.dat
#plt.plot(xilin[0],xilin[0]**2.*xilin[1]*2.1,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

plt.xlim(0,200)
plt.ylim(-50,90)
plt.legend()
#plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
plt.show()

tr = 'BGS_BRIGHT-21.5'
zw = '0.1_0.5'
recl = ['IFTreciso','IFTPreciso','MGreciso']
pl = ['k-','r-','b-']
for rec,p in zip(recl,pl):
    fn_txt_rec = dirxi+'recon/b4rec_code_up/xi'+xit+'_'+tr+'_'+rec+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran4_split20.txt'
    xi = np.loadtxt(fn_txt_rec).transpose()
    plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt=p,label=rec)

plt.xlabel('s (Mpc/h)',size=16)
plt.ylabel(r'$s^2\xi_0$',size=16)
plt.minorticks_on()
plt.title(tr+' '+zw)
#xilin = np.loadtxt(os.environ['HOME']+'/code/BAOfit_xs/BAOtemplates/xi0DESI0.43.03.05.015.01.dat').transpose()
#os.environ['HOME']+'/code/BAOfit_xs/BAOtemplates/xi0DESI0.4533515.01.dat
#plt.plot(xilin[0],xilin[0]**2.*xilin[1]*2.1,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{2},\beta=0.4$')

plt.xlim(0,200)
plt.ylim(-50,110)
plt.legend()
#plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
plt.show()
# Out:
# /global/cfs/cdirs/desi/survey/catalogs/edav1/xi/da02/smu/recon/xipoles_BGS_BRIGHT-21.5_IFTreciso_NScomb_0.1_0.5_default_FKP_lin5_njack60_nran10_split20.txt
# /global/cfs/cdirs/desi/survey/catalogs/edav1/xi/da02/smu/recon/xipoles_BGS_BRIGHT-21.5_IFTreciso_NScomb_0.1_0.5_default_FKP_lin4_njack60_nran10_split20.txt

# %%
tr = 'QSO_ELG_LOPnotqso'
zws = ['0.6_0.8','0.8_1.1','1.1_1.6']
bs = 10
for zw in zws:
    fn_txt = dirxi+'xi'+xit+'_'+tr+'_NScomb_'+zw+'_default_depthz_lin10_njack60_nran1_split20.txt'
    xi = np.loadtxt(fn_txt).transpose()
    plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='o',color='teal')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s^2\xi_0$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi0DESI0.71.04.08.015.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]**2.*xilin[1]*.7,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{0.6},\beta=0.7$')

    plt.xlim(0,200)
    plt.ylim(-25,50)
    #plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
    plt.show()
    plt.errorbar(xi[0],xi[0]*xi[3],xi[0]*xi[6],fmt='o',color='teal')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s\xi_2$')
    plt.minorticks_on()
    plt.title(tr+' '+zw)
    xilin = np.loadtxt(baotempdir+'xi2DESI0.71.04.08.015.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]*xilin[1]*.7,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{0.6},\beta=0.7$')
    #plt.savefig(outdir+'xi2'+tr+zw+str(bs)+'.png')
    plt.xlim(0,200)
    #plt.ylim(-25,50)

    plt.show()

# %%
tr = 'LRG_QSO'
zws = ['0.8_1.1']
bs = 5
for zw in zws:
    fn_txt = dirxi+'xi'+xit+'_'+tr+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran1_split20.txt'
    xi = np.loadtxt(fn_txt).transpose()
    plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='o',color='orange')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s^2\xi_0$')
    plt.minorticks_on()
    plt.title('LRGxQSO; 0.8<z<1.1')
    xilin = np.loadtxt(baotempdir+'/xi0DESI0.43.04.08.015.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]**2.*xilin[1]*1.5,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{0.6},\beta=0.7$')

    plt.xlim(0,200)
    plt.ylim(-50,100)
    #plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
    plt.show()
    plt.errorbar(xi[0],xi[0]*xi[3],xi[0]*xi[6],fmt='o',color='orange')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s\xi_2$')
    plt.minorticks_on()
    plt.title('LRGxQSO; 0.8<z<1.1')
    xilin = np.loadtxt(baotempdir+'/xi2DESI0.43.04.08.015.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]*xilin[1]*1.5,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{0.6},\beta=0.7$')

    plt.xlim(0,200)
    #plt.ylim(-25,50)
    #plt.savefig(outdir+'xi2'+tr+zw+str(bs)+'.png')
    plt.show()

# %%
tr = 'LRG_ELG_LOPnotqso'
zws = ['0.8_1.1']
bs = 5
for zw in zws:
    fn_txt = dirxi+'xi'+xit+'_'+tr+'_NScomb_'+zw+'_default_depthz_lin'+str(bs)+'_njack'+njack+'_nran1_split20.txt'
    xi = np.loadtxt(fn_txt).transpose()
    plt.errorbar(xi[0],xi[0]**2.*xi[2],xi[0]**2.*xi[5],fmt='o',color='purple')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s^2\xi_0$')
    plt.minorticks_on()
    plt.title('LRGxELG_LOPnotqso; 0.8<z<1.1')
    xilin = np.loadtxt(baotempdir+'/xi0DESI0.43.04.08.015.00.dat').transpose()
    plt.plot(xilin[0]*1.,xilin[0]**2.*xilin[1]*1.,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{0.6},\beta=0.7$')

    plt.xlim(0,200)
    plt.ylim(-50,60)
    #plt.savefig(outdir+'xi0'+tr+zw+str(bs)+'.png')
    plt.show()
    plt.errorbar(xi[0],xi[0]*xi[3],xi[0]*xi[6],fmt='o',color='purple')
    plt.xlabel('s (Mpc/h)')
    plt.ylabel(r'$s\xi_2$')
    plt.minorticks_on()
    plt.title('LRGxELG_LOPnotqso; 0.8<z<1.1')
    xilin = np.loadtxt(baotempdir+'/xi2DESI0.43.04.08.015.00.dat').transpose()
    plt.plot(xilin[0],xilin[0]*xilin[1]*1.,'k-.',label=r'$\xi_{\rm 0}(z=0),b/D(z)=\sqrt{0.6},\beta=0.7$')

    plt.xlim(0,200)
    #plt.ylim(-25,50)
    #plt.savefig(outdir+'xi2'+tr+zw+str(bs)+'.png')
    plt.show()

# %%
f1 = '/global/cfs/cdirs/desi/survey/catalogs/edav1/xi/da02/smu/recon/xipoles_BGS_BRIGHT-21.5_IFTreciso_NScomb_0.1_0.5_default_depthz_lin4_njack60_nran1_split20.txt'
d1 = np.loadtxt(f1).transpose()
f2 = '/global/cfs/cdirs/desi/survey/catalogs/edav1/xi/da02/smu/recon/b4rec_code_up/xipoles_BGS_BRIGHT-21.5_IFTreciso_NScomb_0.1_0.5_default_depthz_lin4_njack60_nran4_split20.txt'
d2 = np.loadtxt(f2).transpose()

# %%
plt.plot(d1[0],d1[0]**2.*d1[2],'ko')
plt.plot(d2[0],d2[0]**2.*d2[2],'rd')
plt.show()
