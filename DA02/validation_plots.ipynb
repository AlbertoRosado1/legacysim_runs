# %% [markdown]
# https://github.com/adematti/photometry.git

# %%
import sys
sys.path.append("/global/homes/a/arosado/photometry/")

# %%
import os
import logging
import numpy as np
from matplotlib import pyplot as plt

from photometry import TargetSelection, utils, setup_logging

logger = logging.getLogger('DA02')
setup_logging()

plot_dir = '/global/homes/a/arosado/legacysim_runs/DA02/plots'
run = 'north'
region = run[0].upper()
base_dir = '/global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2'
data_fn = os.path.join(base_dir, 'ELGzdone_full_noveto.dat.fits')
randoms_fn = os.path.join(base_dir, 'ELGzdone_0_full_noveto.ran.fits')
hp_fn = '/global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits'
legacysim_fn = os.path.join(os.getenv('CSCRATCH'),'legacysim','dr9','DA02',run,'file0_rs0_skip0','merged','matched_input.fits')
logger.info('Filename: {}'.format(legacysim_fn))
# Out:
# [ 000000.00 ]: 04-22 08:29  DA02            INFO     Filename: /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/matched_input.fits

# %%
def isELG_colors(gflux=None, rflux=None, zflux=None, w1flux=None,
                 w2flux=None, gfiberflux=None, south=True, primary=None,
                 gmarg=0., grmarg=0., rzmarg=0.):
    """
    Apply ELG selection with box enlarged by ``gmarg``, ``grmarg``, ``rzmarg``.

    SV3 selection from https://github.com/desihub/desitarget/blob/7786db0931d23ed20de7ef37a6f07a52072e11ab/py/desitarget/sv3/sv3_cuts.py#L526
    """
    if primary is None:
        primary = np.ones_like(rflux, dtype='?')
    elg = primary.copy()

    # ADM work in magnitudes instead of fluxes. NOTE THIS IS ONLY OK AS
    # ADM the snr masking in ALL OF g, r AND z ENSURES positive fluxes.
    g = 22.5 - 2.5*np.log10(gflux.clip(1e-16))
    r = 22.5 - 2.5*np.log10(rflux.clip(1e-16))
    z = 22.5 - 2.5*np.log10(zflux.clip(1e-16))
    gfib = 22.5 - 2.5*np.log10(gfiberflux.clip(1e-16))

    # ADM cuts shared by the northern and southern selections.
    elg &= g > 20 - gmarg                # bright cut.
    elg &= r - z > 0.15 - rzmarg         # blue cut.
#    elg &= r - z < 1.6 + rzmarg         # red cut.

    # ADM cuts that are unique to the north or south. Identical for sv3
    # ADM but keep the north/south formalism in case we use it later.
    if south:
        elg &= gfib < 24.1 + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.
    else:
        elg &= gfib < 24. + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.

    # ADM separate a low-priority and a regular sample.
    elgvlo = elg.copy()

    # ADM low-priority OII flux cut.
    elgvlo &= g - r < -1.2*(r - z) + 1.6 + grmarg
    elgvlo &= g - r >= -1.2*(r - z) + 1.3 - grmarg

    # ADM high-priority OII flux cut.
    elg &= g - r < -1.2*(r - z) + 1.3 + grmarg

    return elgvlo, elg


def mask_ts(self,key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region,gmarg=0.,grmarg=0.,rzmarg=0.,gcut=-np.inf):
    mask = isELG_colors(gflux=self['{}_G'.format(key_flux)],rflux=self['{}_R'.format(key_flux)],
                        zflux=self['{}_Z'.format(key_flux)],gfiberflux=self['{}_G'.format(key_fiberflux)],south=region=='S',
                        gmarg=gmarg,grmarg=grmarg,rzmarg=rzmarg)
    mask = mask[0] | mask[1]
    mask &= self['{}_G'.format(key_flux)] > gcut
    return mask

TargetSelection.mask_ts = mask_ts

# %%
# legacysim
legacysim = TargetSelection.load_objects(legacysim_fn, radecbox=None, tracer='ELG', region=None)
legacysim.set_upper_case()
legacysim['RA'] = legacysim['INPUT_RA']
legacysim['DEC'] = legacysim['INPUT_DEC']
#legacysim['MATCHED'] = legacysim['DISTANCE'] < 0.15/3600.
logger.info('Found {:d}/{:d} matches.'.format(legacysim['MATCHED'].sum(),legacysim.size))
for b in legacysim.bands:
    legacysim['INPUT_EFLUX_{}'.format(b)] = utils.mag_to_flux(legacysim['INPUT_{}'.format(b)])
legacysim['INPUT_EFIBERFLUX_G'] = utils.mag_to_flux(legacysim['INPUT_GFIBER'])
legacysim.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
legacysim['EFIBERFLUX_G'] = legacysim.estimated_flux('G',key_transmission='MW_TRANSMISSION',key_flux='FIBERFLUX')
mask_tsin = legacysim.mask_ts(key_flux='INPUT_EFLUX',key_fiberflux='INPUT_EFIBERFLUX',region=region)
#mask_tsin &= legacysim.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
mask_tsout = legacysim.mask_ts(key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region) & legacysim['MATCHED']
#mask_tsout &= legacysim.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
logger.info('Selecting {:d} (output)/{:d} (input) injected sources.'.format(mask_tsout.sum(),mask_tsin.sum()))
legacysim_data = legacysim[mask_tsout]
legacysim_randoms = legacysim[mask_tsin]
# Out:
# [ 000008.37 ]: 04-20 06:47  Catalogue       INFO     Loading catalogue /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/matched_input.fits.
# [ 000026.68 ]: 04-20 06:48  TargetSelection INFO     Selecting 4008897/4008897 targets.
# [ 000043.01 ]: 04-20 06:48  DA02            INFO     Found 2782703/4008897 matches.
# [ 000045.20 ]: 04-20 06:48  DA02            INFO     Selecting 152682 (output)/127285 (input) injected sources.

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)
legacysim_dens = HealpixDensity(map=map)
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)
filename = os.path.join(plot_dir,'footprint_{}.png'.format(run))
legacysim_dens.plot_density_map(title='legacysim density variations',vmin=0,vmax=2)
# Out:
# [ 000056.59 ]: 04-20 06:48  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000056.98 ]: 04-20 06:48  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000057.00 ]: 04-20 06:48  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000057.01 ]: 04-20 06:48  HealpixDensity  INFO     Found 9712 bricks with randoms.

# %%
spectro = True

def mask_data_zok(data, dchi2=0.9, tsnrcut=80):
    mask = data['o2c'] > dchi2
    mask &= data['ZWARN']*0 == 0
    mask &= data['ZWARN'] != 999999
    mask &= data['LOCATION_ASSIGNED'] == 1
    mask &= data['TSNR2_ELG'] > tsnrcut
    return mask

def mask_randoms_zok(randoms, tsnrcut=80):
    mask = randoms['TSNR2_ELG'] > tsnrcut
    return mask

# ELG targets, TS applied already
bricknames = np.unique(legacysim['BRICKNAME'])
logger.info('Found {:d} bricknames'.format(bricknames.size))
data = TargetSelection.load_objects(data_fn,region=region)

mask = np.in1d(data['BRICKNAME'],bricknames)
#mask[:] = True # do not cut data on the same bricks as legacysim
data.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
data['EFIBERFLUX_G'] = data.estimated_flux('G',key_transmission='MW_TRANSMISSION',key_flux='FIBERFLUX')
data.set_mag_from_flux(key_flux='EFLUX')

mask &= data.mask_ts(key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region)
#mask &= data.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
if spectro: mask &= mask_data_zok(data)
data['WEIGHT'] = data.ones()
nreal = 128
#nassign = nreal*data['PROB_OBS'] + 1. #assignment in actual observation counts
#if spectro: data['WEIGHT'] *= (nreal+1)/nassign
if spectro: data['WEIGHT'] *= 1/data['FRACZ_TILELOCID']
logger.info('Selecting {:d}/{:d} targets.'.format(mask.sum(), mask.size))
data = data[mask]

randoms = TargetSelection.load_objects(randoms_fn,region=region)
from desiutil.brick import Bricks
randoms['BRICKNAME'] = Bricks().brickname(randoms['RA'], randoms['DEC'])

mask = np.in1d(randoms['BRICKNAME'],bricknames)
#mask[:] = True
#mask &= randoms.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
if spectro: mask &= mask_randoms_zok(randoms)
randoms = randoms[mask]

def from_map(cat, fields):
    import healpy as hp
    map = Catalogue.load(hp_fn)
    theta,phi = utils.radec_to_thphi(cat['RA'],cat['DEC'])
    hppix = hp.ang2pix(map.header['HPXNSIDE'],theta,phi,nest=map.header['HPXNEST'],lonlat=False)
    for field in fields: cat[field] = map[field][hppix]
# Out:
# [ 000065.08 ]: 04-20 06:48  DA02            INFO     Found 7418 bricknames
# [ 000065.12 ]: 04-20 06:48  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2/ELGzdone_full_noveto.dat.fits.
# [ 000087.32 ]: 04-20 06:49  TargetSelection INFO     Selecting 1388368/4424177 targets.
# <ipython-input-6-f1bb1b9a7c97>:33: RuntimeWarning: divide by zero encountered in true_divide
#   if spectro: data['WEIGHT'] *= 1/data['FRACZ_TILELOCID']
# [ 000092.10 ]: 04-20 06:49  DA02            INFO     Selecting 44626/1388368 targets.
# [ 000092.45 ]: 04-20 06:49  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2/ELGzdone_0_full_noveto.ran.fits.
# [ 000099.94 ]: 04-20 06:49  TargetSelection INFO     Selecting 1423842/4471075 targets.

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)
legacysim_dens = HealpixDensity(map=map)
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)
filename = os.path.join(plot_dir,'footprint_{}.png'.format(run))
legacysim_dens.plot_density_map(title='legacysim density variations',vmin=0,vmax=2,path=filename)

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

dens = HealpixDensity(map=map)
#dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data,key_weight='WEIGHT')

legacysim_dens = HealpixDensity(map=map)
#legacysim_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)

others = [legacysim_dens]
labels = ['DR9','legacysim']

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'density_{}.png'.format(run))
fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000108.30 ]: 04-20 06:49  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000108.63 ]: 04-20 06:49  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000108.66 ]: 04-20 06:49  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000108.66 ]: 04-20 06:49  HealpixDensity  INFO     Found 9712 bricks with randoms.
# [ 000108.72 ]: 04-20 06:49  Utils           INFO     Saving figure to /global/homes/a/arosado/legacysim_runs/DA02/plots/footprint_north.png.
# [ 000109.39 ]: 04-20 06:49  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000109.49 ]: 04-20 06:49  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000109.49 ]: 04-20 06:49  HealpixDensity  INFO     Found 8967 bricks with randoms.
# [ 000109.50 ]: 04-20 06:49  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000109.51 ]: 04-20 06:49  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000109.51 ]: 04-20 06:49  HealpixDensity  INFO     Found 9712 bricks with randoms.
# [ 000109.64 ]: 04-20 06:49  Properties      INFO     Calculating EBV statistics.
# [ 000109.72 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0202.
# [ 000109.72 ]: 04-20 06:49  Properties      INFO     Calculating EBV statistics.
# [ 000109.76 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0202.
# [ 000109.77 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000109.82 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0139.
# [ 000109.82 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000109.86 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0151.
# [ 000109.87 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000109.91 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0143.
# [ 000109.91 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000109.96 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0148.
# [ 000109.96 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000110.01 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0175.
# [ 000110.01 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000110.10 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0179.
# [ 000110.11 ]: 04-20 06:49  Properties      INFO     Calculating STARDENS statistics.
# [ 000110.17 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0164.
# [ 000110.17 ]: 04-20 06:49  Properties      INFO     Calculating STARDENS statistics.
# [ 000110.22 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0170.
# [ 000110.23 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000110.27 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0162.
# [ 000110.28 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000110.32 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0170.
# [ 000110.32 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000110.37 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0191.
# [ 000110.37 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000110.43 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0180.
# [ 000110.44 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000110.49 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0204.
# [ 000110.49 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000110.54 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0204.

# %%
ax = plt.gca()
ax.hist(legacysim['INPUT_SERSIC'], histtype='step', label='input', density=True)
ax.hist(legacysim['SERSIC'], histtype='step', label='output', density=True)
ax.hist(legacysim_data['SERSIC'], histtype='step', label='selected', density=True)
#ax.hist(data['SERSIC'], histtype='step', label='in data', density=True)
ax.legend()

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

others = []
labels = []
for sersic in [0, 1, 4]:
    legacysim_dens = HealpixDensity(map=map)
    #legacysim_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
    legacysim_dens.set_randoms(randoms=legacysim_randoms[legacysim_randoms['INPUT_SERSIC'] == sersic])
    legacysim_dens.set_properties()
    legacysim_dens.set_data(data=legacysim_data[legacysim_data['INPUT_SERSIC'] == sersic])
    others.append(legacysim_dens)
    labels.append('$n = {:d}$'.format(sersic))

dens, others = others[0], others[1:]

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'density_{}.png'.format(run))
fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000125.28 ]: 04-20 06:49  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000125.38 ]: 04-20 06:49  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000125.55 ]: 04-20 06:49  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000125.55 ]: 04-20 06:49  HealpixDensity  INFO     Found 8056 bricks with randoms.
# [ 000125.72 ]: 04-20 06:49  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000125.90 ]: 04-20 06:49  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000125.90 ]: 04-20 06:49  HealpixDensity  INFO     Found 9612 bricks with randoms.
# [ 000126.10 ]: 04-20 06:49  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000126.17 ]: 04-20 06:49  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000126.18 ]: 04-20 06:49  HealpixDensity  INFO     Found 6589 bricks with randoms.
# [ 000126.46 ]: 04-20 06:49  Properties      INFO     Calculating EBV statistics.
# [ 000126.53 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0199.
# [ 000126.54 ]: 04-20 06:49  Properties      INFO     Calculating EBV statistics.
# [ 000126.58 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0202.
# [ 000126.58 ]: 04-20 06:49  Properties      INFO     Calculating EBV statistics.
# [ 000126.62 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0216.
# [ 000126.63 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000126.68 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0213.
# [ 000126.68 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000126.72 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0188.
# [ 000126.73 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000126.77 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0187.
# [ 000126.77 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000126.82 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0187.
# [ 000126.82 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000126.87 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0196.
# [ 000126.87 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000126.92 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0195.
# [ 000126.92 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000126.97 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0203.
# [ 000126.98 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000127.02 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0214.
# [ 000127.02 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000127.06 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0180.
# [ 000127.07 ]: 04-20 06:49  Properties      INFO     Calculating STARDENS statistics.
# [ 000127.11 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0185.
# [ 000127.12 ]: 04-20 06:49  Properties      INFO     Calculating STARDENS statistics.
# [ 000127.16 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0207.
# [ 000127.17 ]: 04-20 06:49  Properties      INFO     Calculating STARDENS statistics.
# [ 000127.21 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0173.
# [ 000127.21 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000127.26 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0203.
# [ 000127.26 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000127.30 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0210.
# [ 000127.30 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000127.35 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0198.
# [ 000127.35 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000127.40 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0194.
# [ 000127.40 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000127.44 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0216.
# [ 000127.44 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000127.48 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0193.
# [ 000127.49 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000127.53 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0202.
# [ 000127.53 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000127.59 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0220.
# [ 000127.60 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000127.65 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0167.

# %%
from photometry import Catalogue, HealpixDensity

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

dens = HealpixDensity(map=map)
#dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data,key_weight='WEIGHT')

others = []
labels = ['DR9']

for sersic in [None, 1]:
    legacysim_dens = HealpixDensity(map=map)
    #legacysim_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
    if sersic is not None:
        legacysim_dens.set_randoms(randoms=legacysim_randoms[legacysim_randoms['INPUT_SERSIC'] == sersic])
    else:
        legacysim_dens.set_randoms(randoms=legacysim_randoms)
    legacysim_dens.set_properties()
    if sersic is not None:
        legacysim_dens.set_data(data=legacysim_data[legacysim_data['INPUT_SERSIC'] == sersic])
    else:
        legacysim_dens.set_data(data=legacysim_data)
    others.append(legacysim_dens)
    labels.append('legacysim' if sersic is None else 'legacysim $n = {:d}$'.format(sersic))

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'density_{}.png'.format(run))
fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000135.75 ]: 04-20 06:49  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000135.82 ]: 04-20 06:49  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000135.82 ]: 04-20 06:49  HealpixDensity  INFO     Found 8967 bricks with randoms.
# [ 000135.83 ]: 04-20 06:49  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000135.84 ]: 04-20 06:49  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000135.84 ]: 04-20 06:49  HealpixDensity  INFO     Found 9712 bricks with randoms.
# [ 000135.86 ]: 04-20 06:49  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000136.09 ]: 04-20 06:49  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000136.09 ]: 04-20 06:49  HealpixDensity  INFO     Found 9612 bricks with randoms.
# [ 000136.55 ]: 04-20 06:49  Properties      INFO     Calculating EBV statistics.
# [ 000136.63 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0202.
# [ 000136.63 ]: 04-20 06:49  Properties      INFO     Calculating EBV statistics.
# [ 000136.67 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0202.
# [ 000136.68 ]: 04-20 06:49  Properties      INFO     Calculating EBV statistics.
# [ 000136.72 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0199.
# [ 000136.73 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000136.77 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0139.
# [ 000136.77 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000136.82 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0151.
# [ 000136.82 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000136.86 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0147.
# [ 000136.87 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000136.91 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0143.
# [ 000136.91 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000136.95 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0148.
# [ 000136.96 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000137.00 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0148.
# [ 000137.01 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000137.07 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0175.
# [ 000137.07 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000137.13 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0179.
# [ 000137.13 ]: 04-20 06:49  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000137.18 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0174.
# [ 000137.18 ]: 04-20 06:49  Properties      INFO     Calculating STARDENS statistics.
# [ 000137.24 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0164.
# [ 000137.24 ]: 04-20 06:49  Properties      INFO     Calculating STARDENS statistics.
# [ 000137.29 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0170.
# [ 000137.29 ]: 04-20 06:49  Properties      INFO     Calculating STARDENS statistics.
# [ 000137.33 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0168.
# [ 000137.34 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000137.39 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0162.
# [ 000137.39 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000137.45 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0170.
# [ 000137.46 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000137.52 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0173.
# [ 000137.53 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000137.58 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0191.
# [ 000137.58 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000137.62 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0180.
# [ 000137.63 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000137.67 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0178.
# [ 000137.68 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000137.74 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0204.
# [ 000137.74 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000137.79 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0204.
# [ 000137.79 ]: 04-20 06:49  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000137.85 ]: 04-20 06:49  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0207.
