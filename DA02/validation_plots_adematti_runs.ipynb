# %%
import sys
sys.path.append("/global/homes/a/arosado/photometry/")

# %%
import os
import logging
import numpy as np
import fitsio as ft
from matplotlib import pyplot as plt

from photometry import TargetSelection, utils, setup_logging

# %% [markdown]
# I used `ELGzdone_full_noveto.dat.fits` while Arnaud used `ELGzdone_full.dat.fits`

# %%
import os
import logging
import numpy as np
import fitsio as ft
from matplotlib import pyplot as plt

from photometry import TargetSelection, utils, setup_logging

logger = logging.getLogger('DA02')
setup_logging()

plot_dir = '/global/homes/a/arosado/legacysim_runs/DA02/plots'
run = 'north'
region = run[0].upper()
base_dir = '/global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2'
data_fn = os.path.join(base_dir, 'ELGzdone_full_noveto.dat.fits')
randoms_fn = os.path.join(base_dir, 'ELGzdone_0_full_noveto.ran.fits')
hp_fn = '/global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits'
legacysim_fn = os.path.join(os.getenv('CSCRATCH'),'legacysim','dr9','DA02',run,'file0_rs0_skip0','merged','adematti_matched_input.fits')
logger.info('Filename: {}'.format(legacysim_fn))
# Out:
# [ 000000.00 ]: 05-03 15:00  DA02            INFO     Filename: /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/adematti_matched_input.fits

# %%
my_base_dir = '/global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2'
my_data_fn = os.path.join(base_dir, 'ELGzdone_full_noveto.dat.fits')
my_randoms_fn = os.path.join(base_dir, 'ELGzdone_0_full_noveto.ran.fits')
my_legacysim_fn = os.path.join(os.getenv('CSCRATCH'),'legacysim','dr9','DA02',run,'file0_rs0_skip0','merged','matched_input.fits')
logger.info('Filename: {}'.format(my_legacysim_fn))
# Out:
# [ 000000.92 ]: 05-03 15:00  DA02            INFO     Filename: /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/matched_input.fits

# %% [markdown]
# # Functions

# %%
def isELG_colors(gflux=None, rflux=None, zflux=None, w1flux=None,
                 w2flux=None, gfiberflux=None, south=True, primary=None,
                 gmarg=0., grmarg=0., rzmarg=0.):
    """
    Apply ELG selection with box enlarged by ``gmarg``, ``grmarg``, ``rzmarg``.

    SV3 selection from https://github.com/desihub/desitarget/blob/7786db0931d23ed20de7ef37a6f07a52072e11ab/py/desitarget/sv3/sv3_cuts.py#L526
    """
    if primary is None:
        primary = np.ones_like(rflux, dtype='?')
    elg = primary.copy()

    # ADM work in magnitudes instead of fluxes. NOTE THIS IS ONLY OK AS
    # ADM the snr masking in ALL OF g, r AND z ENSURES positive fluxes.
    g = 22.5 - 2.5*np.log10(gflux.clip(1e-16))
    r = 22.5 - 2.5*np.log10(rflux.clip(1e-16))
    z = 22.5 - 2.5*np.log10(zflux.clip(1e-16))
    gfib = 22.5 - 2.5*np.log10(gfiberflux.clip(1e-16))

    # ADM cuts shared by the northern and southern selections.
    elg &= g > 20 - gmarg                # bright cut.
    elg &= r - z > 0.15 - rzmarg         # blue cut.
#    elg &= r - z < 1.6 + rzmarg         # red cut.

    # ADM cuts that are unique to the north or south. Identical for sv3
    # ADM but keep the north/south formalism in case we use it later.
    if south:
        elg &= gfib < 24.1 + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.
    else:
        elg &= gfib < 24. + gmarg  # faint cut.
        elg &= g - r < 0.5*(r - z) + 0.1 + grmarg  # remove stars, low-z galaxies.

    # ADM separate a low-priority and a regular sample.
    elgvlo = elg.copy()

    # ADM low-priority OII flux cut.
    elgvlo &= g - r < -1.2*(r - z) + 1.6 + grmarg
    elgvlo &= g - r >= -1.2*(r - z) + 1.3 - grmarg

    # ADM high-priority OII flux cut.
    elg &= g - r < -1.2*(r - z) + 1.3 + grmarg

    return elgvlo, elg


def mask_ts(self,key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region,gmarg=0.,grmarg=0.,rzmarg=0.,gcut=-np.inf):
    mask = isELG_colors(gflux=self['{}_G'.format(key_flux)],rflux=self['{}_R'.format(key_flux)],
                        zflux=self['{}_Z'.format(key_flux)],gfiberflux=self['{}_G'.format(key_fiberflux)],south=region=='S',
                        gmarg=gmarg,grmarg=grmarg,rzmarg=rzmarg)
    mask = mask[0] | mask[1]
    mask &= self['{}_G'.format(key_flux)] > gcut
    return mask

TargetSelection.mask_ts = mask_ts

# %% [markdown]
# # Code

# %% [markdown]
# Get bricks that are same for both runs

# %%
my_bricks = np.unique(ft.FITS(my_legacysim_fn)[1]['input_brickname'][:])
adematti_bricks = np.unique(ft.FITS(legacysim_fn)[1]['input_brickname'][:])
mask = np.isin(adematti_bricks, my_bricks)
bricks2use = adematti_bricks[mask]
bricks2use.size
# Out:
# 7685

# %% [markdown]
# Arnaud's results (only choose bricks in my run)

# %%
# legacysim
legacysim = TargetSelection.load_objects(legacysim_fn, radecbox=None, tracer='ELG', region=None)
legacysim.set_upper_case()

# here we select only the bricks I ran
compare_mask = np.isin(legacysim['INPUT_BRICKNAME'], bricks2use)
legacysim = legacysim[compare_mask]

#continue the same as always
legacysim['RA'] = legacysim['INPUT_RA']
legacysim['DEC'] = legacysim['INPUT_DEC']
#legacysim['MATCHED'] = legacysim['DISTANCE'] < 0.15/3600.
logger.info('Found {:d}/{:d} matches.'.format(legacysim['MATCHED'].sum(),legacysim.size))
for b in legacysim.bands:
    legacysim['INPUT_EFLUX_{}'.format(b)] = utils.mag_to_flux(legacysim['INPUT_{}'.format(b)])
legacysim['INPUT_EFIBERFLUX_G'] = utils.mag_to_flux(legacysim['INPUT_GFIBER'])
legacysim.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
legacysim['EFIBERFLUX_G'] = legacysim.estimated_flux('G',key_transmission='MW_TRANSMISSION',key_flux='FIBERFLUX')
mask_tsin = legacysim.mask_ts(key_flux='INPUT_EFLUX',key_fiberflux='INPUT_EFIBERFLUX',region=region)
#mask_tsin &= legacysim.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
mask_tsout = legacysim.mask_ts(key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region) & legacysim['MATCHED']
#mask_tsout &= legacysim.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
logger.info('Selecting {:d} (output)/{:d} (input) injected sources.'.format(mask_tsout.sum(),mask_tsin.sum()))
legacysim_data = legacysim[mask_tsout]
legacysim_randoms = legacysim[mask_tsin]
# Out:
# [ 000030.04 ]: 05-03 15:00  Catalogue       INFO     Loading catalogue /global/cscratch1/sd/arosado/legacysim/dr9/DA02/north/file0_rs0_skip0/merged/adematti_matched_input.fits.
# [ 000054.05 ]: 05-03 15:01  TargetSelection INFO     Selecting 5592566/5592566 targets.
# [ 000086.51 ]: 05-03 15:01  DA02            INFO     Found 2883122/4153756 matches.
# [ 000088.89 ]: 05-03 15:01  DA02            INFO     Selecting 158417 (output)/132033 (input) injected sources.

# %%
np.unique(legacysim['INPUT_BRICKNAME']).size
# Out:
# 7685

# %% [markdown]
# ## plotting Arnaud's

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)
legacysim_dens = HealpixDensity(map=map)
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)
filename = os.path.join(plot_dir,'adematti_footprint_{}.png'.format(run))
legacysim_dens.plot_density_map(title='legacysim density variations',vmin=0,vmax=2)
# Out:
# [ 000092.73 ]: 05-03 15:01  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000092.90 ]: 05-03 15:01  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000092.92 ]: 05-03 15:01  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000092.92 ]: 05-03 15:01  HealpixDensity  INFO     Found 10137 bricks with randoms.

# %%
spectro = True

def mask_data_zok(data, dchi2=0.9, tsnrcut=80):
    mask = data['o2c'] > dchi2
    mask &= data['ZWARN']*0 == 0
    mask &= data['ZWARN'] != 999999
    mask &= data['LOCATION_ASSIGNED'] == 1
    mask &= data['TSNR2_ELG'] > tsnrcut
    return mask

def mask_randoms_zok(randoms, tsnrcut=80):
    mask = randoms['TSNR2_ELG'] > tsnrcut
    return mask

# ELG targets, TS applied already
bricknames = np.unique(legacysim['BRICKNAME'])
logger.info('Found {:d} bricknames'.format(bricknames.size))
data = TargetSelection.load_objects(data_fn,region=region)

mask = np.in1d(data['BRICKNAME'],bricknames)
#mask[:] = True # do not cut data on the same bricks as legacysim
data.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
data['EFIBERFLUX_G'] = data.estimated_flux('G',key_transmission='MW_TRANSMISSION',key_flux='FIBERFLUX')
data.set_mag_from_flux(key_flux='EFLUX')

mask &= data.mask_ts(key_flux='EFLUX',key_fiberflux='EFIBERFLUX',region=region)
#mask &= data.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
if spectro: mask &= mask_data_zok(data)
data['WEIGHT'] = data.ones()
nreal = 128
#nassign = nreal*data['PROB_OBS'] + 1. #assignment in actual observation counts
#if spectro: data['WEIGHT'] *= (nreal+1)/nassign
if spectro: data['WEIGHT'] *= 1/data['FRACZ_TILELOCID']
logger.info('Selecting {:d}/{:d} targets.'.format(mask.sum(), mask.size))
data = data[mask]

randoms = TargetSelection.load_objects(randoms_fn,region=region)
from desiutil.brick import Bricks
randoms['BRICKNAME'] = Bricks().brickname(randoms['RA'], randoms['DEC'])

mask = np.in1d(randoms['BRICKNAME'],bricknames)
#mask[:] = True
#mask &= randoms.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
if spectro: mask &= mask_randoms_zok(randoms)
randoms = randoms[mask]

def from_map(cat, fields):
    import healpy as hp
    map = Catalogue.load(hp_fn)
    theta,phi = utils.radec_to_thphi(cat['RA'],cat['DEC'])
    hppix = hp.ang2pix(map.header['HPXNSIDE'],theta,phi,nest=map.header['HPXNEST'],lonlat=False)
    for field in fields: cat[field] = map[field][hppix]
# Out:
# [ 000094.28 ]: 05-03 15:01  DA02            INFO     Found 7686 bricknames
# [ 000094.33 ]: 05-03 15:01  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2/ELGzdone_full_noveto.dat.fits.
# [ 000113.87 ]: 05-03 15:02  TargetSelection INFO     Selecting 1388368/4424177 targets.
# <ipython-input-10-f1bb1b9a7c97>:33: RuntimeWarning: divide by zero encountered in true_divide
#   if spectro: data['WEIGHT'] *= 1/data['FRACZ_TILELOCID']
# [ 000118.83 ]: 05-03 15:02  DA02            INFO     Selecting 46876/1388368 targets.
# [ 000119.14 ]: 05-03 15:02  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/2/ELGzdone_0_full_noveto.ran.fits.
# [ 000126.19 ]: 05-03 15:02  TargetSelection INFO     Selecting 1423842/4471075 targets.

# %%
from photometry import Catalogue, HealpixDensity

# Density maps
map = Catalogue.load(hp_fn)
legacysim_dens = HealpixDensity(map=map)
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)
filename = os.path.join(plot_dir,'adematti_footprint_{}.png'.format(run))
legacysim_dens.plot_density_map(title='legacysim density variations',vmin=0,vmax=2,path=filename)

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

dens = HealpixDensity(map=map)
#dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data,key_weight='WEIGHT')

legacysim_dens = HealpixDensity(map=map)
#legacysim_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
legacysim_dens.set_randoms(randoms=legacysim_randoms)
legacysim_dens.set_properties()
legacysim_dens.set_data(data=legacysim_data)

others = [legacysim_dens]
labels = ['DR9','legacysim']

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'adematti_density_{}.png'.format(run))
#fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 000130.00 ]: 05-03 15:02  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000130.07 ]: 05-03 15:02  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000130.09 ]: 05-03 15:02  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000130.10 ]: 05-03 15:02  HealpixDensity  INFO     Found 10137 bricks with randoms.
# [ 000130.16 ]: 05-03 15:02  Utils           INFO     Saving figure to /global/homes/a/arosado/legacysim_runs/DA02/plots/adematti_footprint_north.png.
# [ 000130.82 ]: 05-03 15:02  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000130.88 ]: 05-03 15:02  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000130.88 ]: 05-03 15:02  HealpixDensity  INFO     Found 9438 bricks with randoms.
# [ 000130.89 ]: 05-03 15:02  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000130.90 ]: 05-03 15:02  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000130.90 ]: 05-03 15:02  HealpixDensity  INFO     Found 10137 bricks with randoms.
# [ 000131.04 ]: 05-03 15:02  Properties      INFO     Calculating EBV statistics.
# [ 000131.09 ]: 05-03 15:02  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0193.
# [ 
]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0197.
# [ 002663.81 ]: 05-03 15:44  Properties      INFO     Calculating EBV statistics.
# [ 002663.86 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0196.
# [ 002663.87 ]: 05-03 15:44  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 002663.92 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0137.
# [ 002663.92 ]: 05-03 15:44  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 002663.97 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0144.
# [ 002663.97 ]: 05-03 15:44  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 002664.02 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0145.
# [ 002664.03 ]: 05-03 15:44  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 002664.08 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0142.
# [ 002664.08 ]: 05-03 15:44  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 002664.13 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0143.
# [ 002664.13 ]: 05-03 15:44  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 002664.18 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0145.
# [ 002664.19 ]: 05-03 15:44  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 002664.24 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0173.
# [ 002664.24 ]: 05-03 15:44  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 002664.29 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0178.
# [ 002664.29 ]: 05-03 15:44  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 002664.34 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0174.
# [ 002664.34 ]: 05-03 15:44  Properties      INFO     Calculating STARDENS statistics.
# [ 002664.39 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0151.
# [ 002664.40 ]: 05-03 15:44  Properties      INFO     Calculating STARDENS statistics.
# [ 002664.44 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0149.
# [ 002664.45 ]: 05-03 15:44  Properties      INFO     Calculating STARDENS statistics.
# [ 002664.49 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0145.
# [ 002664.50 ]: 05-03 15:44  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 002664.55 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0165.
# [ 002664.55 ]: 05-03 15:44  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 002664.60 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0164.
# [ 002664.60 ]: 05-03 15:44  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 002664.65 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0167.
# [ 002664.65 ]: 05-03 15:44  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 002664.71 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0187.
# [ 002664.71 ]: 05-03 15:44  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 002664.76 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0175.
# [ 002664.76 ]: 05-03 15:44  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 002664.81 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0171.
# [ 002664.81 ]: 05-03 15:44  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 002664.87 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0200.
# [ 002664.87 ]: 05-03 15:44  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 002664.92 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0199.
# [ 002664.92 ]: 05-03 15:44  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 002664.97 ]: 05-03 15:44  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0194.

# %% [markdown]
# # TEST CODE

# %%
dens

# %%
# Step 1
import pickle
 
# Step 2
with open('adematti_dens', 'wb') as density_variation_file:
 
  # Step 3
    pickle.dump(dens, density_variation_file)

# %%
# Step 1
import pickle
 
# Step 2
with open('adematti_dens', 'rb') as density_variation_file:
 
    # Step 3
    adematti_dens = pickle.load(density_variation_file)
 
    # After adematti_dens is read from file
    print(adematti_dens)
# Out:
# <photometry.density_variations.HealpixDensity object at 0x15552bbb6d30>

# %%
others
# Out:
# [<photometry.density_variations.HealpixDensity at 0x15552464f1f0>,
#  <photometry.density_variations.HealpixDensity at 0x1555243e0ee0>]

# %%
# Step 1
import pickle
 
# Step 2
with open('adematti_others', 'wb') as others_file:
 
  # Step 3
    pickle.dump(others, others_file)

# %%
# Step 1
import pickle
 
# Step 2
with open('adematti_others', 'rb') as others_file:
 
    # Step 3
    adematti_others = pickle.load(others_file)
 
    # After adematti_dens is read from file
    print(adematti_others)
# Out:
# [<photometry.density_variations.HealpixDensity object at 0x155524cac940>, <photometry.density_variations.HealpixDensity object at 0x155524ae9d00>]

# %%
fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(20,8))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
    adematti_dens.plot_density_variations(ax=lax[iax],others=adematti_others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},ylim=(-0.1,0.1),xedges={'quantiles':[0.01,0.99]})
filename = os.path.join(plot_dir,'adematti_density_{}.png'.format(run))
#fig.savefig(filename, bbox_inches='tight', pad_inches=0.1, dpi=200)
plt.show()
# Out:
# [ 004305.81 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0193.
# [ 004305.82 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0197.
# [ 004305.82 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0196.
# [ 004305.84 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0193.
# [ 004305.84 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0197.
# [ 004305.85 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0196.
# [ 004305.87 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0137.
# [ 004305.87 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0144.
# [ 004305.88 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0145.
# [ 004305.89 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0137.
# [ 004305.89 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0144.
# [ 004305.90 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0145.
# [ 004305.91 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0142.
# [ 004305.91 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0143.
# [ 004305.92 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0145.
# [ 004305.93 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0142.
# [ 004306.09 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0143.
# [ 004306.10 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0145.
# [ 004306.11 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0173.
# [ 004306.12 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0178.
# [ 004306.12 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0174.
# [ 004306.13 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0173.
# [ 004306.14 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0178.
# [ 004306.14 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0174.
# [ 004306.15 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0151.
# [ 004306.16 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0149.
# [ 004306.16 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0145.
# [ 004306.17 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0151.
# [ 004306.18 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0149.
# [ 004306.18 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0145.
# [ 004306.19 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0165.
# [ 004306.19 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0164.
# [ 004306.20 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0167.
# [ 004306.21 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0165.
# [ 004306.22 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0164.
# [ 004306.22 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0167.
# [ 004306.23 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0187.
# [ 004306.24 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0175.
# [ 004306.24 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0171.
# [ 004306.25 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0187.
# [ 004306.26 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0175.
# [ 004306.26 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0171.
# [ 004306.27 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0200.
# [ 004306.28 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0199.
# [ 004306.28 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0194.
# [ 004306.29 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0200.
# [ 004306.30 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0199.
# [ 004306.30 ]: 05-03 16:12  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0194.
